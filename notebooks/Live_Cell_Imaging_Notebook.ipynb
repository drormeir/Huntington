# %%
import warnings

def custom_warn(message, category, filename, lineno, file=None, line=None):
    print(f'[{category.__name__}] {filename}:{lineno} --> {message}', flush=True)
warnings.showwarning = custom_warn

# %% [markdown]
# ### Porting to Google Colab
# The following cell enables this notebook to run from Google Colab as well as from your local machine IDE.<br>
# You can change `root_directory` and/or `this_notebook_google_path` to point to the directory in your Google account, which contains this notebook, together with the `imgs` sub-directory and the rest of the files.<br>

# %%
import sys
import os
try:
    from google.colab import drive as google_drive
except:
    # no Google Colab --> fall back to local machine
    google_drive = None

if google_drive is not None:
    google_drive_directory = os.path.join('/','content','gdrive')
    google_drive.mount(google_drive_directory)
    all_projects_path = os.path.join(google_drive_directory, 'Othercomputers','My Laptop', 'projects')
else:
    all_projects_path = os.path.join('d:\\', 'projects')

project_path = os.path.join(all_projects_path,'BioTAU','Huntington')
assert os.path.exists(project_path), f'Project path {project_path} not found!'
# enable import python files from this notebook's path
sys.path.append(project_path)
# enable reading images and data files from this notebook's path
os.chdir(project_path)

datasets_path = os.path.join(project_path, 'datasets')
assert os.path.exists(datasets_path), f'Datasets path {datasets_path} not found!'

output_path = os.path.join(project_path, 'output')
os.makedirs(output_path, exist_ok=True)
assert os.path.exists(output_path), f'Output path {output_path} not found!'

print(f'Current working directory: {os.getcwd()}')
print(f'Datasets path: {datasets_path}')
print(f'Output path: {output_path}')
# Out:
# Current working directory: d:\projects\BioTAU\Huntington
# Datasets path: d:\projects\BioTAU\Huntington\datasets
# Output path: d:\projects\BioTAU\Huntington\output

# %% [markdown]
# # Read Live Data

# %%
from python.Live_Cell_Imaging import Live_Cell_Imaging

# %%
live_data = Live_Cell_Imaging(file_name=None, verbose=2)
# Out:
# Reading Live_Cell_Imaging from file_name='d:\\projects\\BioTAU\\Huntington\\datasets\\Live_Cell_Imaging.csv'
# [UserWarning] d:\projects\BioTAU\Huntington\python\csv_pd.py:150 --> For file: "d:\projects\BioTAU\Huntington\datasets\Live_Cell_Imaging.csv" There are 3 duplicate columns to be removed:
# ['Cell Type', 'Severity', 'PC']
# Patients_Catalog: match id='4717' --> id_2_check='4717' --> catalog_id=GM04717
# Patients_Catalog: match id='143' --> id_2_check='143' --> catalog_id=HGADFN0143  Zero age!
# Patients_Catalog: match id='4285' --> id_2_check='4285' --> catalog_id=GM04285
# Patients_Catalog: match id='848' --> id_2_check='848' --> catalog_id=NA0848
# Patients_Catalog: match id='4847' --> id_2_check='4847' --> catalog_id=GM04847
# Patients_Catalog: match id='4799' --> id_2_check='4799' --> catalog_id=GM04799
# Patients_Catalog: match id='4687' --> id_2_check='4687' --> catalog_id=GM04687
# Patients_Catalog: match id='1170' --> id_2_check='1170' --> catalog_id=NA1170
# Patients_Catalog: match id='4689' --> id_2_check='4689' --> catalog_id=GM04689
# Patients_Catalog: match id='4715' --> id_2_check='4715' --> catalog_id=GM04715
# Patients_Catalog: match id='971' --> id_2_check='971' --> catalog_id=NA0971
# Patients_Catalog: match id='4767' --> id_2_check='4767' --> catalog_id=GM04767
# Patients_Catalog: match id='305' --> id_2_check='305' --> catalog_id=GM00305
# Patients_Catalog: match id='495' --> id_2_check='495' --> catalog_id=NA0495
# Patients_Catalog: match id='4807' --> id_2_check='4807' --> catalog_id=GM04807
# Patients_Catalog: match id='4693' --> id_2_check='4693' --> catalog_id=GM04693
# Patients_Catalog: match id='4721' --> id_2_check='4721' --> catalog_id=GM04721
# Patients_Catalog: match id='4719' --> id_2_check='4719' --> catalog_id=GM04719
#
# Live_Cell_Imaging Wells Count
# ==================================================
# Patient_ID
# GM00305       28
# GM04285       27
# GM04687       30
# GM04689       18
# GM04693       19
# GM04715       19
# GM04717       30
# GM04719       10
# GM04721        8
# GM04767       19
# GM04799       20
# GM04807       17
# GM04847       11
# HGADFN0143    36
# NA0495        16
# NA0848        11
# NA0971        20
# NA1170        12
# Name: Num_Wells, dtype: int64
#    modified_spots_chanel_4_Total_Spot_Area_Mean_per_Well  \
# 0                                                 5.1569
# 1                                                 5.4081
# 2                                                 5.5340
# 3                                                 5.1667
# 4                                                 5.4172
#
#    modified_spots_chanel_4_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                         0.7662
# 1                                                         0.7754
# 2                                                         0.7800
# 3                                                         0.7746
# 4                                                         0.7762
#
#    modified_spots_chanel_4_Number_of_Spots_Mean_per_Well  \
# 0                                                 0.9692
# 1                                                 0.9816
# 2                                                 0.9769
# 3                                                 0.9734
# 4                                                 0.9731
#
#    modified_spots_chanel_4_Number_of_Spots_per_Area_of_modified_spots_chanel_4_Mean_per_Well  \
# 0                                                                                     0.2151
# 1                                                                                     0.2113
# 2                                                                                     0.2099
# 3                                                                                     0.2161
# 4                                                                                     0.2097
#
#    modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well  \
# 0                                                11.0731
# 1                                                 9.4181
# 2                                                 9.4707
# 3                                                 9.1054
# 4                                                 8.9101
#
#    modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                         0.7422
# 1                                                         0.7252
# 2                                                         0.7234
# 3                                                         0.7208
# 4                                                         0.7153
#
#    modified_spots_chanel_3_Number_of_Spots_Mean_per_Well  \
# 0                                                 1.2063
# 1                                                 1.1254
# 2                                                 1.1226
# 3                                                 1.1199
# 4                                                 1.0988
#
#    modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well  \
# 0                                                                                     0.1229
# 1                                                                                     0.1315
# 2                                                                                     0.1315
# 3                                                                                     0.1342
# 4                                                                                     0.1348
#
#    modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area  \
# 0                                                2.5928
# 1                                                1.7142
# 2                                                1.7081
# 3                                                1.6165
# 4                                                1.4928
#
#    modified_ir_chanel_3_at_modified_ir_chanel_3_at_Roundness_Mean_per_Well  \
# 0                                                                   1.1223
# 1                                                                   1.2012
# 2                                                                   1.1997
# 3                                                                   1.2172
# 4                                                                   1.2370
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    spots_chanel_3_final_spots_chanel_3_final_Radial_Mean_SER-Spot_Mean_per_Well  \
# 0                                                                        1.0974
# 1                                                                        1.0655
# 2                                                                        1.0872
# 3                                                                        1.0447
# 4                                                                        1.0607
#
#    spots_chanel_3_final_spots_chanel_3_final_Radial_Relative_Deviation_SER-Spot_Mean_per_Well  \
# 0                                                                                      0.4076
# 1                                                                                      0.4041
# 2                                                                                      0.4014
# 3                                                                                      0.3977
# 4                                                                                      0.3999
#
#    spots_chanel_3_final_spots_chanel_3_final_Radial_Mean_Ratio_SER-Spot_Mean_per_Well  \
# 0                                                                              0.8566
# 1                                                                              0.8680
# 2                                                                              0.8736
# 3                                                                              0.8694
# 4                                                                              0.8754
#
#    spots_chanel_3_final_spots_chanel_3_final_Profile_1/2_SER-Spot_Mean_per_Well  \
# 0                                                                        0.2856
# 1                                                                        0.3153
# 2                                                                        0.3161
# 3                                                                        0.3206
# 4                                                                        0.3301
#
#    spots_chanel_3_final_spots_chanel_3_final_Profile_2/2_SER-Spot_Mean_per_Well  \
# 0                                                                        0.4686
# 1                                                                        0.5062
# 2                                                                        0.5007
# 3                                                                        0.5077
# 4                                                                        0.5207
#
#    ir_chanel_4_total_ir_chanel_4_total_Area  \
# 0                                61626.5859
# 1                                84084.8828
# 2                                63089.0625
# 3                                62002.6875
# 4                                54857.7500
#
#    ir_chanel_3_total_ir_chanel_3_total_Area  total_ir_chanel_4_normalized  \
# 0                               227741.7344                      125.2573
# 1                               185937.2812                      164.2283
# 2                               145357.3125                      151.2927
# 3                               161733.6250                      116.1099
# 4                               107974.8281                      165.2342
#
#    total_ir_chanel_3_normalized  Patient_ID
# 0                      462.8897     GM04717
# 1                      363.1588     GM04717
# 2                      348.5787     GM04717
# 3                      302.8719     GM04717
# 4                      325.2254     GM04717
#
# [5 rows x 173 columns]
# Features columns:
# ['modified_spots_chanel_4_Total_Spot_Area_Mean_per_Well', 'modified_spots_chanel_4_Relative_Spot_Intensity_Mean_per_Well', 'modified_spots_chanel_4_Number_of_Spots_Mean_per_Well', 'modified_spots_chanel_4_Number_of_Spots_per_Area_of_modified_spots_chanel_4_Mean_per_Well', 'modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well', 'modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Roundness_Mean_per_Well', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Width', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Length', 'modified_ir_chanel_4_at_modified_ir_chanel_4_at_Area', 'modified_ir_chanel_4_at_modified_ir_chanel_4_at_Roundness_Mean_per_Well', 'modified_ir_chanel_4_at_modified_ir_chanel_4_at_Width', 'modified_ir_chanel_4_at_modified_ir_chanel_4_at_Length', 'All_Cells_Number_of_Objects', 'All_Cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well', 'All_Cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well', 'All_Cells_chanel_2_Gabor_Max_2_px_w2_Mean_per_Well', 'All_Cells_chanel_1_Gabor_Max_2_px_w2_Mean_per_Well', 'All_Cells_chanel_3_SER_Spot_1_px_Mean_per_Well', 'All_Cells_chanel_3_SER_Hole_1_px_Mean_per_Well', 'All_Cells_chanel_3_SER_Ridge_1_px_Mean_per_Well', 'All_Cells_chanel_3_SER_Valley_1_px_Mean_per_Well', 'All_Cells_chanel_4_SER_Spot_1_px_Mean_per_Well', 'All_Cells_chanel_4_SER_Hole_1_px_Mean_per_Well', 'All_Cells_chanel_4_SER_Ridge_1_px_Mean_per_Well', 'All_Cells_chanel_4_SER_Valley_1_px_Mean_per_Well', 'All_Cells_chanel_2_SER_Spot_1_px_Mean_per_Well', 'All_Cells_chanel_2_SER_Hole_1_px_Mean_per_Well', 'All_Cells_chanel_2_SER_Ridge_1_px_Mean_per_Well', 'All_Cells_chanel_2_SER_Valley_1_px_Mean_per_Well', 'All_Cells_chanel_1_SER_Spot_1_px_Mean_per_Well', 'All_Cells_chanel_1_SER_Hole_1_px_Mean_per_Well', 'All_Cells_chanel_1_SER_Ridge_1_px_Mean_per_Well', 'All_Cells_chanel_1_SER_Valley_1_px_Mean_per_Well', 'All_Cells_chanel_3_intensity_Mean_Mean_per_Well', 'All_Cells_chanel_3_intensity_Sum_Sum_per_Well', 'All_Cells_chanel_2_Area', 'All_Cells_chanel_2_Roundness_Mean_per_Well', 'All_Cells_chanel_2_Width', 'All_Cells_chanel_2_Length', 'All_Cells_chanel_1_Area', 'All_Cells_chanel_1_Roundness_Mean_per_Well', 'All_Cells_chanel_1_Width', 'All_Cells_chanel_1_Length', 'All_Cells_chanel_4_intensity_Mean_Mean_per_Well', 'All_Cells_chanel_4_intensity_Sum_Sum_per_Well', 'All_Cells_chanel_2_intensity_Mean_Mean_per_Well', 'All_Cells_chanel_1_intensity_Mean_Mean_per_Well', 'All_Cells_chanel_1_Symmetry_02__Mean_per_Well', 'All_Cells_chanel_1_Symmetry_03__Mean_per_Well', 'All_Cells_chanel_1_Symmetry_04__Mean_per_Well', 'All_Cells_chanel_1_Symmetry_05__Mean_per_Well', 'All_Cells_chanel_1_Symmetry_12__Mean_per_Well', 'All_Cells_chanel_1_Symmetry_13__Mean_per_Well', 'All_Cells_chanel_1_Symmetry_14__Mean_per_Well', 'All_Cells_chanel_1_Symmetry_15__Mean_per_Well', 'All_Cells_chanel_1_Threshold_Compactness_30%__Mean_per_Well', 'All_Cells_chanel_1_Threshold_Compactness_40%__Mean_per_Well', 'All_Cells_chanel_1_Threshold_Compactness_50%__Mean_per_Well', 'All_Cells_chanel_1_Threshold_Compactness_60%__Mean_per_Well', 'All_Cells_chanel_1_Axial_Small_Length__Mean_per_Well', 'All_Cells_chanel_1_Axial_Length_Ratio__Mean_per_Well', 'All_Cells_chanel_1_Radial_Mean__Mean_per_Well', 'All_Cells_chanel_1_Radial_Relative_Deviation__Mean_per_Well', 'All_Cells_chanel_1_Profile_1/2__Mean_per_Well', 'All_Cells_chanel_1_Profile_2/2__Mean_per_Well', 'All_Cells_chanel_2_Symmetry_02__Mean_per_Well', 'All_Cells_chanel_2_Symmetry_03__Mean_per_Well', 'All_Cells_chanel_2_Symmetry_04__Mean_per_Well', 'All_Cells_chanel_2_Symmetry_05__Mean_per_Well', 'All_Cells_chanel_2_Symmetry_12__Mean_per_Well', 'All_Cells_chanel_2_Symmetry_13__Mean_per_Well', 'All_Cells_chanel_2_Symmetry_14__Mean_per_Well', 'All_Cells_chanel_2_Symmetry_15__ ...

# %%
#live_data.simple_feature_enginearing_classify_HD_without_HGPS()
#live_data.evaluate_features_by_xgboost_classify_HD_without_HGPS(cv_monte_carlo=10, verbose=2)
live_data.evaluate_features_by_xgboost_to_classify_patients_HD_without_HGPS(verbose=2)
# Out:
# Evaluating features using XGBoost: 100%|██████████| 2737/2737 [42:57<00:00,  1.06it/s]
# Selected model has 172 features with final accuracy: 100.00%
# Feature[ 1] = spots_chanel_4_final_spots_chanel_4_final_Radial_Mean_Ratio_SER-Spot_Mean_per_Well
# Feature[ 2] = All_Cells_chanel_1_Symmetry_04__Mean_per_Well
# Feature[ 3] = spots_chanel_4_final_spots_chanel_4_final_Radial_Relative_Deviation__Mean_per_Well
# Feature[ 4] = All_Cells_chanel_1_Length
# Feature[ 5] = All_Cells_chanel_2_intensity_Mean_Mean_per_Well
# Feature[ 6] = spots_chanel_4_final_spots_chanel_4_final_Threshold_Compactness_40%__Mean_per_Well
# Feature[ 7] = All_Cells_chanel_1_Symmetry_02__Mean_per_Well
# Feature[ 8] = All_Cells_chanel_1_Radial_Relative_Deviation__Mean_per_Well
# Feature[ 9] = All_Cells_chanel_2_SER_Valley_1_px_Mean_per_Well
# Feature[10] = All_Cells_chanel_4_SER_Spot_1_px_Mean_per_Well
# Feature[11] = All_Cells_chanel_4_SER_Hole_1_px_Mean_per_Well
# Feature[12] = All_Cells_chanel_2_SER_Hole_1_px_Mean_per_Well
# Feature[13] = spots_chanel_3_final_spots_chanel_3_final_Radial_Mean_Ratio_SER-Spot_Mean_per_Well
# Feature[14] = All_Cells_chanel_4_Profile_5/5__Mean_per_Well
# Feature[15] = All_Cells_chanel_3_Profile_1/5__Mean_per_Well
# Feature[16] = All_Cells_chanel_1_Symmetry_14__Mean_per_Well
# Feature[17] = All_Cells_chanel_3_Threshold_Compactness_40%__Mean_per_Well
# Feature[18] = All_Cells_chanel_3_Threshold_Compactness_30%__Mean_per_Well
# Feature[19] = All_Cells_chanel_4_intensity_Mean_Mean_per_Well
# Feature[20] = All_Cells_chanel_1_Symmetry_15__Mean_per_Well
# Feature[21] = All_Cells_chanel_2_Roundness_Mean_per_Well
# Feature[22] = All_Cells_chanel_3_Radial_Mean__Mean_per_Well
# Feature[23] = All_Cells_chanel_2_Threshold_Compactness_60%__Mean_per_Well
# Feature[24] = All_Cells_chanel_3_Profile_3/5__Mean_per_Well
# Feature[25] = spots_chanel_4_final_spots_chanel_4_final_Profile_1/2_SER-Spot_Mean_per_Well
# Feature[26] = All_Cells_chanel_1_Profile_1/2__Mean_per_Well
# Feature[27] = spots_chanel_4_final_spots_chanel_4_final_Radial_Relative_Deviation_SER-Spot_Mean_per_Well
# Feature[28] = All_Cells_chanel_3_Threshold_Compactness_50%__Mean_per_Well
# Feature[29] = All_Cells_chanel_1_Symmetry_12__Mean_per_Well
# Feature[30] = All_Cells_chanel_1_Radial_Mean__Mean_per_Well
# Feature[31] = spots_chanel_3_final_spots_chanel_3_final_Profile_2/2_SER-Spot_Mean_per_Well
# Feature[32] = spots_chanel_4_final_spots_chanel_4_final_Threshold_Compactness_50%__Mean_per_Well
# Feature[33] = All_Cells_chanel_4_SER_Ridge_1_px_Mean_per_Well
# Feature[34] = All_Cells_chanel_4_SER_Valley_1_px_Mean_per_Well
# Feature[35] = All_Cells_chanel_4_Threshold_Compactness_40%__Mean_per_Well
# Feature[36] = All_Cells_chanel_4_Profile_1/5__Mean_per_Well
# Feature[37] = All_Cells_chanel_1_Axial_Length_Ratio__Mean_per_Well
# Feature[38] = All_Cells_chanel_1_Roundness_Mean_per_Well
# Feature[39] = All_Cells_chanel_2_Threshold_Compactness_30%__Mean_per_Well
# Feature[40] = All_Cells_chanel_2_Symmetry_03__Mean_per_Well
# Feature[41] = All_Cells_chanel_1_Symmetry_05__Mean_per_Well
# Feature[42] = All_Cells_chanel_1_Area
# Feature[43] = All_Cells_chanel_1_Profile_2/2__Mean_per_Well
# Feature[44] = All_Cells_chanel_2_Length
# Feature[45] = All_Cells_chanel_4_Threshold_Compactness_30%__Mean_per_Well
# Feature[46] = All_Cells_chanel_1_SER_Valley_1_px_Mean_per_Well
# Feature[47] = All_Cells_chanel_4_Threshold_Compactness_50%__Mean_per_Well
# Feature[48] = All_Cells_chanel_2_Profile_3/5__Mean_per_Well
# Feature[49] = All_Cells_chanel_1_Gabor_Max_2_px_w2_Mean_per_Well
# Feature[50] = All_Cells_chanel_2_Profile_2/5__Mean_per_Well
# Feature[51] = All_Cells_Number_of_Objects
# Feature[52] = spots_chanel_4_final_spots_chanel_4_final_Threshold_Compactness_30%__Mean_per_Well
# Feature[53] = All_Cells_chanel_2_Symmetry_13__Mean_per_Well
# Feature[54] = spots_chanel_4_final_spots_chanel_4_final_Roundness_Mean_per_Well
# Feature[55] = All_Cells_chanel_3_Profile_4/5__Mean_per_Well
# Feature[56] = total_ir_chanel_4_normalized
# Feature[57] = All_Cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well
# Feature[58] = spots_chanel_4_final_spots_chanel_4_final_Profile_2/2_SER-Spot_Mean_per_Well
# Feature[59] = All_Cells_chanel_2_Symmetry_04__Mean_per_Well
# Feature[60] = All_Cells_chanel_2_Symmetry_14__Mean_per_Well
# Feature[61] = modified_ir_chanel_4_at_modified_ir_chanel_4_at_Length
# Feature[62] = All_Cells_chanel_2_Symmetry_12__Mean_per_Well
# Feature[63] = All_Cells_chanel_2_Area
# Feature[64] = spots_chanel_4_final_spots_chanel_4_final_Threshold_Compactness_60%__Mean_per_Well
# Feature[65] = All_Cells_chanel_1_Threshold_Compactness_60%__Mean_per_Well
# Feature[66] = modified_spots_chanel_4_Number_of_Spots_per_Area_of_modified_spots_chanel_4_Mean_per_Well
# Feature[67] = All_Cells_chanel_3_Radial_Relative_Deviation__Mean_per_Well
# Feature[68] = All_Cells_chanel_1_SER_Ridge_1_px_Mean_per_Well
# Feature[69] = All_Cells_chanel_3_SER_Spot_1_px_Mean_per_Well
# Feature[70] = All_Cells_chanel_4_Threshold_Compactness_60%__Mean_per_Well
# Feature[71] = All_Cells_chanel_2_Radial_Relative_Deviation__Mean_per_Well
# Feature[72] = All_Cells_chanel_2_Axial_Small_Length__Mean_per_Well
# Feature[73] = All_Cells_chanel_2_SER_Ridge_1_px_Mean_per_Well
# Feature[74] = spots_chanel_4_final_spots_chanel_4_final_Threshold_Compactness_60%_SER-Spot_Mean_per_Well
# Feature[75] = All_Cells_chanel_4_Profile_2/5__Mean_per_Well
# Feature[76] = All_Cells_chanel_3_Threshold_Compactness_60%__Mean_per_Well
# Feature[77] = modified_spots_chanel_4_Relative_Spot_Intensity_Mean_per_Well
# Feature[78] = All_Cells_chanel_2_Radial_Mean__Mean_per_Well
# Feature[79] = spots_chanel_4_final_spots_chanel_4_final_Threshold_Compactness_30%_SER-Spot_Mean_per_Well
# Feature[80] = spots_chanel_4_final_spots_chanel_4_final_Threshold_Compactness_50%_SER-Spot_Mean_per_Well
# Feature[81] = All_Cells_chanel_1_SER_Spot_1_px_Mean_per_Well
# Feature[82] = spots_chanel_3_final_spots_chanel_3_final_Threshold_Compactness_50%__Mean_per_Well
# Feature[83] = All_Cells_chanel_2_Symmetry_05__Mean_per_Well
# Feature[84] = All_Cells_chanel_3_Profile_5/5__Mean_per_Well
# Feature[85] = All_Cells_chanel_2_Symmetry_02__Mean_per_Well
# Feature[86] = All_Cells_chanel_2_Threshold_Compactness_40%__Mean_per_Well
# Feature[87] = modified_spots_chanel_4_Number_of_Spots_Mean_per_Well
# Feature[88] = modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well
# Feature[89] = spots_chanel_4_final_Spot_Area
# Feature[90] = All_Cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well
# Feature[91] = All_Cells_chanel_2_Profile_1/5__Mean_per_Well
# Feature[92] = modified_spots_chanel_4_Total_Spot_Area_Mean_per_Well
# Feature[93] = spots_chanel_3_final_spots_chanel_3_final_Radial_Mean__Mean_per_Well
# Feature[94] = All_Cells_chanel_1_Threshold_Compactness_50%__Mean_per_Well
# Feature[95] = spots_chanel_3_final_spots_chanel_3_final_Radial_Relative_Deviation_SER-Spot_Mean_per_Well
# Feature[96] = All_Cells_chanel_1_Threshold_Compactness_40%__Mean_per_Well
# Feature[97] = spots_chanel_3_final_spots_chanel_3_final_Threshold_Compactness_60%_SER-Spot_Mean_per_Well
# Feature[98] = modified_ir_chanel_4_at_modified_ir_chanel_4_at_Width
# Feature[99] = All_Cells_chanel_1_Axial_Small_Length__Mean_per_Well
# Feature[100] = All_Cells_chanel_3_SER_Ridge_1_px_Mean_per_Well
# Feature[101] = All_Cells_chanel_2_Threshold_Compactness_50%__Mean_per_Well
# Feature[102] = All_Cells_chanel_2_Profile_4/5__Mean_per_Well
# Feature[103] = modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well
# Feature[104] = spots_chanel_4_final_Relative_Spot_Intensity_Mean_per_Well
# Feature[105] = spots_chanel_4_final_Corrected_Spot_Intensity_Mean_per_Well
# Feature[106] = All_Cells_chanel_1_Width
# Feature[107] = spots_chanel_4_final_Spot_to_Region_Intensity_Mean_per_Well
# Feature[108] = spots_chanel_4_final_spots_chanel_4_final_Radial_Mean__Mean_per_Well
# Feature[109] = modified_ir_chanel_4_at_modified_ir_chanel_4_at_Roundness_Mean_per_Well
# Feature[110] = All_Cells_chanel_2_Symmetry_15__Mean_per_Well
# Feature[111] = All_Cells_chanel_2_Gabor_Max_2_px_w2_Mean_per_Well
# Feature[112] = All_Cells_chanel_1_intensity_Mean_Mean_per_Well
# Feature[113] = spots_chanel_3_final_Spot_Area
# Feature[114] = All_Cells_chanel_2_SER_Spot_1_px_Mean_per_Well
# Feature[115] = spots_chanel_4_final_spots_chanel_4_final_Profile_2/2__Mean_per_Well
# Feature[116] = All_Cells_chanel_1_Symmetry_03__Mean_per_Well
# Feature[117] = ir_chanel_4_total_ir_chanel_4_total_Area
# Feature[118] = All_Cells_chanel_3_Profile_2/5__Mean_per_Well
# Feature[119] = spots_chanel_3_final_spots_chanel_3_final_Threshold_Compactness_40%_SER-Spot_Mean_per_Well
# Feature[120] = spots_chanel_4_final_spots_chanel_4_final_Threshold_Compactness_40%_SER-Spot_Mean_per_Well
# Feature[121] = All_Cells_chanel_2_Profile_5/5__Mean_per_Well
# Feature[122] = All_Cells_chanel_3_intensity_Sum_Sum_per_Well
# Feature[123] = modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area
# Feature[124] = spots_chanel_4_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well
# Feature[125] = spots_chanel_4_final_spots_chanel_4_final_Profile_1/2__Mean_per_Well
# Feature[126] = spots_chanel_3_final_Spot_Contrast_Mean_per_Well
# Feature[127] = All_Cells_chanel_4_Profile_4/5__Mean_per_Well
# Feature[128] = spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well
# Feature[129] = All_Cells_chanel_1_SER_Hole_1_px_Mean_per_Well
# Feature[130] = spots_chanel_4_final_spots_chanel_4_final_Length
# Feature[131] = spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well
# Feature[132] = modified_ir_chanel_3_at_modified_ir_chanel_3_at_Roundness_Mean_per_Well
# Feature[133] = spots_chanel_3_final_spots_chanel_3_final_Profile_1/2_SER-Spot_Mean_per_Well
# Feature[134] = All_Cells_chanel_2_Axial_Length_Ratio__Mean_per_Well
# Feature[135] = spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well
# Feature[136] = spots_chanel_4_final_spots_chanel_4_final_Area
# Feature[137] = modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well
# Feature[138] = All_Cells_chanel_3_SER_Hole_1_px_Mean_per_Well
# Feature[139] = spots_chanel_3_final_spots_chanel_3_final_Radial_Mean_SER-Spot_Mean_per_Well
# Feature[140] = modified_ir_chanel_4_at_modified_ir_chanel_4_at_Area
# Feature[141] = spots_chanel_3_final_spots_chanel_3_final_Threshold_Compactness_30%_SER-Spot_Mean_per_Well
# Feature[142] = modified_ir_chanel_3_at_modified_ir_chanel_3_at_Width
# Feature[143] = spots_chanel_3_final_spots_chanel_3_final_Threshold_Compactness_30%__Mean_per_Well
# Feature[144] = All_Cells_chanel_4_Profile_3/5__Mean_per_Well
# Feature[145] = spots_chanel_3_final_spots_chanel_3_final_Width
# Feature[146] = spots_chanel_3_final_Region_Intensity_Mean_per_Well
# Feature[147] = modified_spots_chanel_3_Number_of_Spots_Mean_per_Well
# Feature[148] = spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well
# Feature[149] = spots_chanel_3_final_spots_chanel_3_final_Threshold_Compactness_40%__Mean_per_Well
# Feature[150] = spots_chanel_4_final_spots_chanel_4_final_Radial_Mean_SER-Spot_Mean_per_Well
# Feature[151] = spots_chanel_4_final_Spot_Background_Intensity_Mean_per_Well
# Feature[152] = spots_chanel_4_final_Spot_Contrast_Mean_per_Well
# Feature[153] = All_Cells_chanel_3_SER_Valley_1_px_Mean_per_Well
# Feature[154] = modified_ir_chanel_3_at_modified_ir_chanel_3_at_Length
# Feature[155] = All_Cells_chanel_3_intensity_Mean_Mean_per_Well
# Feature[156] = spots_chanel_4_final_Region_Intensity_Mean_per_Well
# Feature[157] = All_Cells_chanel_2_Width
# Feature[158] = All_Cells_chanel_4_intensity_Sum_Sum_per_Well
# Feature[159] = All_Cells_chanel_1_Threshold_Compactness_30%__Mean_per_Well
# Feature[160] = All_Cells_chanel_1_Symmetry_13__Mean_per_Well
# Feature[161] = spots_chanel_4_final_spots_chanel_4_final_Width
# Feature[162] = spots_chanel_3_final_spots_chanel_3_final_Profile_1/2__Mean_per_Well
# Feature[163] = spots_chanel_3_final_spots_chanel_3_final_Radial_Relative_Deviation__Mean_per_Well
# Feature[164] = spots_chanel_3_final_spots_chanel_3_final_Threshold_Compactness_60%__Mean_per_Well
# Feature[165] = spots_chanel_3_final_spots_chanel_3_final_Roundness_Mean_per_Well
# Feature[166] = spots_chanel_3_final_spots_chanel_3_final_Area
# Feature[167] = spots_chanel_3_final_spots_chanel_3_final_Length
# Feature[168] = spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well
# Feature[169] = spots_chanel_3_final_spots_chanel_3_final_Profile_2/2__Mean_per_Well
# Feature[170] = spots_chanel_3_final_spots_chanel_3_final_Threshold_Compactness_50%_SER-Spot_Mean_per_Well
# Feature[171] = ir_chanel_3_total_ir_chanel_3_total_Area
# Feature[172] = total_ir_chanel_3_normalized
