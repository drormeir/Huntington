# %%
import warnings

def custom_warn(message, category, filename, lineno, file=None, line=None):
    print(f'[{category.__name__}] {filename}:{lineno} --> {message}', flush=True)
warnings.showwarning = custom_warn

# %% [markdown]
# ### Porting to Google Colab
# The following cell enables this notebook to run from Google Colab as well as from your local machine IDE.<br>
# You can change `root_directory` and/or `this_notebook_google_path` to point to the directory in your Google account, which contains this notebook, together with the `imgs` sub-directory and the rest of the files.<br>

# %%
import sys
import os
try:
    from google.colab import drive as google_drive
except:
    # no Google Colab --> fall back to local machine
    google_drive = None

if google_drive is not None:
    google_drive_directory = os.path.join('/','content','gdrive')
    google_drive.mount(google_drive_directory)
    all_projects_path = os.path.join(google_drive_directory, 'Othercomputers','My Laptop', 'projects')
else:
    all_projects_path = os.path.join('d:\\', 'projects')

project_path = os.path.join(all_projects_path,'BioTAU','Huntington')
assert os.path.exists(project_path), f'Project path {project_path} not found!'
# enable import python files from this notebook's path
sys.path.append(project_path)
# enable reading images and data files from this notebook's path
os.chdir(project_path)

datasets_path = os.path.join(project_path, 'datasets')
assert os.path.exists(datasets_path), f'Datasets path {datasets_path} not found!'

output_path = os.path.join(project_path, 'output')
os.makedirs(output_path, exist_ok=True)
assert os.path.exists(output_path), f'Output path {output_path} not found!'

print(f'Current working directory: {os.getcwd()}')
print(f'Datasets path: {datasets_path}')
print(f'Output path: {output_path}')
# Out:
# Current working directory: d:\projects\BioTAU\Huntington
# Datasets path: d:\projects\BioTAU\Huntington\datasets
# Output path: d:\projects\BioTAU\Huntington\output

# %%
from python.Migration_Data import Migration_Data, HGPS_Plate_Results, HGPS_Data_APRW, LatB_LowHigh_MitoQ_APRW

# %%
file_name_DataFileLatB = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'Migration', 'DataFileLatB.csv')
file_name_DataFileMitoQ = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'Migration', 'DataFileMitoQ.csv')
file_name_DataFileWithHGPS = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'Migration', 'DataFileWithHGPS.csv')
file_name_HGPS_PlateResults = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'HGPS_PlateResults.csv')
file_name_HGPS_PlateResults_5 = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- exp5 plate1 08.01.23__2023-01-12T15_50_14-Measurement 1.csv')
file_name_HGPS_PlateResults_6 = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- exp6  05.02.23__2023-02-19T12_14_21-Measurement 1.csv')
file_name_HGPS_PlateResults_7 = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- exp7 06.02.23__2023-02-19T14_31_42-Measurement 1.csv')
file_name_HGPS_PlateResults_8 = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- exp8 12.02.23__2023-02-20T14_52_23-Measurement 1.csv')
file_name_HGPS_PlateResults_4R = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- R exp4 05.07.22__2022-07-17T09_42_44-Measurement 1.csv')
file_name_HGPS_PlateResults_4Sa = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- S exp4 05.07.22 (9-10)__2022-07-12T11_44_17-Measurement 1.csv')
file_name_HGPS_PlateResults_4Sb = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- S exp4 05.07.22__2022-07-12T10_09_44-Measurement 1.csv')
file_name_HGPS_Data_APRW_Model = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data', 'HGPS_Data', 'APRW Model Features Wells Created.csv')
file_name_LatB_LowHigh_APRW_Model = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data', 'LatB_LowHigh', 'APRW Model Features.csv')
file_name_MitoQ_APRW_Model = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data', 'MitoQ_Media_DMSO_Cleaned_75', 'APRW Model Features.csv')

# %% [markdown]
# # Read Migration Data

# %%
LatB_LowHigh_APRW_data = LatB_LowHigh_MitoQ_APRW(file_name=file_name_LatB_LowHigh_APRW_Model,verbose=2)
# Out:
# Reading LatB_LowHigh_MitoQ_APRW: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\LatB_LowHigh\APRW Model Features.csv
# Patients_Catalog: match id='AG01512' --> id_2_check='AG015' --> catalog_id_2_check='AG015' --> AG0015
# Patients_Catalog: match id='NA07309' --> id_2_check='NA0730' --> NA0730
# Patients_Catalog: match id='NA08788' --> id_2_check='NA0878' --> NA0878
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0481913' --> id_2_check='GM04819' --> GM04819
# Patient_ID
# AG0015     4
# NA0730     4
# NA0878     4
# GM04212    1
# GM04819    1
# Name: Num_Wells, dtype: int64

# %%
MitoQ_APRW_data = LatB_LowHigh_MitoQ_APRW(file_name=file_name_MitoQ_APRW_Model,verbose=2)
# Out:
# Reading LatB_LowHigh_MitoQ_APRW: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\MitoQ_Media_DMSO_Cleaned_75\APRW Model Features.csv
# Patients_Catalog: match id='NA01438' --> id_2_check='NA0143' --> NA0143
# Patients_Catalog: match id='NA07309' --> id_2_check='NA0730' --> NA0730
# Patients_Catalog: match id='GM041968' --> id_2_check='GM04196' --> GM04196
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0471511' --> id_2_check='GM04715' --> GM04715
# Patients_Catalog: extact match id='GM01653'
# Patients_Catalog: extact match id='NA0971'
# Patients_Catalog: extact match id='NA1170'
# Patients_Catalog: extact match id='GM00305'
# Patients_Catalog: extact match id='GM02165'
# Patients_Catalog: extact match id='GM04847'
# Patients_Catalog: extact match id='GM04689'
# Patients_Catalog: extact match id='GM04693'
# Patients_Catalog: extact match id='GM04837'
# Patients_Catalog: extact match id='NA0143'
# Patients_Catalog: extact match id='GM04285'
# Patients_Catalog: extact match id='GM04687'
# Patients_Catalog: extact match id='GM04691'
# Patients_Catalog: extact match id='GM04767'
# Patients_Catalog: extact match id='GM04807'
# Patients_Catalog: extact match id='GM04849'
# Patient_ID
# NA0143      5
# NA0730      2
# GM04196     2
# GM04212     3
# GM04715     2
# GM01653     8
# NA0971      6
# NA1170     11
# GM00305     2
# GM02165     2
# GM04847     2
# GM04689     2
# GM04693     2
# GM04837     3
# GM04285     1
# GM04687     1
# GM04691     3
# GM04767     3
# GM04807     2
# GM04849     2
# Name: Num_Wells, dtype: int64

# %%
HGPS_data_APRW = HGPS_Data_APRW(file_name=file_name_HGPS_Data_APRW_Model,verbose=2)
# Out:
# Reading HGPS_Data_APRW: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\HGPS_Data\APRW Model Features Wells Created.csv
# Patients_Catalog: match id='NA014310' --> id_2_check='NA0143' --> NA0143
# Patients_Catalog: match original_ID='NA0165017' --> id='GM0165017' --> id_2_check='GM01650' --> GM01650
# Patients_Catalog: match original_ID='NA0165320' --> id='GM0165320' --> id_2_check='GM01653' --> GM01653
# Patients_Catalog: match id='NA049513' --> id_2_check='NA0495' --> NA0495
# Patients_Catalog: match id='NA084813' --> id_2_check='NA0848' --> NA0848
# Patients_Catalog: match id='NA097110' --> id_2_check='NA0971' --> NA0971
# Patients_Catalog: match id='NA117014' --> id_2_check='NA1170' --> NA1170
# Patients_Catalog: match original_ID='NA4614610' --> id='AG1614610' --> id_2_check='AG16146' --> AG16146
# Patients_Catalog: match original_ID='NAIC016' --> id='NA0016' --> id_2_check='NA001' --> catalog_id_2_check='NA00143' --> NA0143
# Patients_Catalog: match original_ID='NAIC025' --> id='NA0025'
# Patients_Catalog: match original_ID='NAIC143' --> id='NA0143'
# Patients_Catalog: match original_ID='NAIC157' --> id='NA0157'
# Patients_Catalog: match original_ID='NAIC170' --> id='NA0170' --> id_2_check='NA01' --> NA0143
# Patients_Catalog: match original_ID='NAIC233' --> id='NA0233'
# Patients_Catalog: match original_ID='NAIC234' --> id='NA0234'
# Patients_Catalog: match original_ID='NAIC477' --> id='NA0477'
# Patients_Catalog: match original_ID='NAIC561' --> id='NA0561'
# Patients_Catalog: match original_ID='NAIC579' --> id='NA0579'
# Patients_Catalog: match original_ID='NAIC633' --> id='NA0633'
# Patients_Catalog: match original_ID='NAIC769' --> id='NA0769'
# Patients_Catalog: match original_ID='NAIC878' --> id='NA0878'
# Patients_Catalog: match original_ID='GMIC42128' --> id='GM042128' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match original_ID='GM04484909' --> id='GM0484909' --> id_2_check='GM04849' --> GM04849
# Patients_Catalog: match id='GM0476713' --> id_2_check='GM04767' --> GM04767
# Patients_Catalog: match original_ID='GMIC41968' --> id='GM041968' --> id_2_check='GM04196' --> GM04196
# Patients_Catalog: match original_ID='GMIC4709' --> id='GM04709'
# Patients_Catalog: match original_ID='GMIC4715' --> id='GM04715'
# Patients_Catalog: match original_ID='GMIC48878' --> id='GM048878' --> id_2_check='GM04887' --> GM04887
# Patients_Catalog: match original_ID='GM0568716' --> id='GM0468716' --> id_2_check='GM04687' --> GM04687
# Patients_Catalog: match id='GM0469109' --> id_2_check='GM04691' --> GM04691
# Patients_Catalog: match original_ID='GMIC214712' --> id='GM0214712' --> id_2_check='GM02147' --> GM02147
# Patients_Catalog: match original_ID='GM04484715' --> id='GM0484715' --> id_2_check='GM04847' --> GM04847
# Patients_Catalog: match original_ID='GMIC4287' --> id='GM04287'
# Patients_Catalog: match id='GM0030518' --> id_2_check='GM00305' --> GM00305
# Patients_Catalog: match id='GM0428510' --> id_2_check='GM04285' --> GM04285
# Patients_Catalog: match original_ID='GMIC62748' --> id='GM062748' --> id_2_check='GM06274' --> GM06274
# Patients_Catalog: match original_ID='GMIC4200' --> id='GM04200'
# Patients_Catalog: match original_ID='GMIC447610' --> id='GM0447610' --> id_2_check='GM04476' --> GM04476
# Patients_Catalog: match original_ID='GMIC5031' --> id='GM05031'
# Patients_Catalog: match id='GM0216516' --> id_2_check='GM02165' --> GM02165
# Patients_Catalog: match id='GM0483713' --> id_2_check='GM04837' --> GM04837
# Patients_Catalog: match id='GM0468911' --> id_2_check='GM04689' --> GM04689
# Patients_Catalog: match original_ID='GMIC4717' --> id='GM04717'
# Patients_Catalog: match id='GM0469309' --> id_2_check='GM04693' --> GM04693
# Patients_Catalog: match id='GM0484714' --> id_2_check='GM04847' --> GM04847
# Patients_Catalog: match original_ID='GMIC4719' --> id='GM04719'
# Patients_Catalog: match original_ID='GMIC4721' --> id='GM04721'
# Patients_Catalog: match original_ID='GMIC47997' --> id='GM047997' --> id_2_check='GM04799' --> GM04799
# Patients_Catalog: match original_ID='GMIC48198' --> id='GM048198' --> id_2_check='GM04819' --> GM04819
# Patients_Catalog: match original_ID='pro12218' --> id='HGADFN12218' --> id_2_check='HGADFN122' --> catalog_id_2_check='HGADFN122' --> HGADFN0122
# Patients_Catalog: match original_ID='pro12716' --> id='HGADFN12716' --> id_2_check='HGADFN127' --> catalog_id_2_check='HGADFN127' --> HGADFN0127
# Patients_Catalog: match original_ID='pro16915' --> id='HGADFN16915' --> id_2_check='HGADFN169' --> catalog_id_2_check='HGADFN169' --> HGADFN0169
# Patients_Catalog: match original_ID='pro18816' --> id='HGADFN18816' --> id_2_check='HGADFN188' --> catalog_id_2_check='HGADFN188' --> HGADFN0188
# Patients_Catalog: match original_ID='pro27113' --> id='HGADFN27113' --> id_2_check='HGADFN271' --> catalog_id_2_check='HGADFN271' --> HGADFN0271
# Patients_Catalog: match original_ID='pro36713' --> id='HGADFN36713' --> id_2_check='HGADFN367' --> catalog_id_2_check='HGADFN367' --> HGADFN0367
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=NA0165017 --> selected_id='GM0165017' --> ret_id='GM01650'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=NA0165320 --> selected_id='GM0165320' --> ret_id='GM01653'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=NA4614610 --> selected_id='AG1614610' --> ret_id='AG16146'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=GM04484909 --> selected_id='GM0484909' --> ret_id='GM04849'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=GM0568716 --> selected_id='GM0468716' --> ret_id='GM04687'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=GM04484715 --> selected_id='GM0484715' --> ret_id='GM04847'
#   warnings.warn(str_warn)
# Patient_ID
# NA1170        18
# GM04847       18
# GM00305       12
# GM04689       12
# GM04837       12
# GM04693       12
# GM02165       11
# GM01653        9
# NA0495         6
# NA0971         6
# HGADFN0127     6
# GM04767        6
# GM04849        6
# AG16146        6
# GM04687        6
# HGADFN0169     6
# HGADFN0188     6
# HGADFN0122     6
# NA0143         6
# HGADFN0367     6
# GM04285        6
# GM04691        6
# HGADFN0271     6
# GM01650        3
# NA0848         3
# NA0769         1
# NA0878         1
# NA0233         1
# NA0157         1
# NA0025         1
# NA0633         1
# NA0579         1
# NA0561         1
# NA0477         1
# NA0234         1
# GM04212        1
# GM04476        1
# GM06274        1
# GM04287        1
# GM02147        1
# GM04196        1
# GM04887        1
# GM04715        1
# GM04709        1
# GM04200        1
# GM04717        1
# GM05031        1
# GM04721        1
# GM04719        1
# GM04799        1
# GM04819        1
# Name: Num_Wells, dtype: int64

# %%
HGPS_Results = HGPS_Plate_Results(file_name=file_name_HGPS_PlateResults, verbose=2)
HGPS_PlateResults_5 = HGPS_Plate_Results(file_name_HGPS_PlateResults_5, verbose=2)
HGPS_PlateResults_6 = HGPS_Plate_Results(file_name_HGPS_PlateResults_6, verbose=2)
HGPS_PlateResults_7 = HGPS_Plate_Results(file_name_HGPS_PlateResults_7, verbose=2)
HGPS_PlateResults_8 = HGPS_Plate_Results(file_name_HGPS_PlateResults_8, verbose=2)
HGPS_PlateResults_4R = HGPS_Plate_Results(file_name_HGPS_PlateResults_4R, verbose=2)
HGPS_PlateResults_4Sa = HGPS_Plate_Results(file_name_HGPS_PlateResults_4Sa, verbose=2)
HGPS_PlateResults_4Sb = HGPS_Plate_Results(file_name_HGPS_PlateResults_4Sb, verbose=2)
# Out:
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\HGPS_PlateResults.csv
# Patients_Catalog: match id='12213' --> id_2_check='122' --> HGADFN0122
# Patients_Catalog: match original_ID='16' --> id='0016' --> id_2_check='0016' --> catalog_id_2_check='GM001650' --> GM01650
# Patients_Catalog: match original_ID='13' --> id='0013' --> id_2_check='0013' --> HGADFN0013  Zero age!
# Patients_Catalog: match id='1514' --> id_2_check='15' --> AG0015
# Patients_Catalog: match id='12715' --> id_2_check='127' --> HGADFN0127
# Patient_ID
# HGADFN0122    12
# GM01650       12
# HGADFN0013    12
# AG0015        12
# HGADFN0127    12
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp5 plate1 08.01.23__2023-01-12T15_50_14-Measurement 1.csv
# Patients_Catalog: match id='4717' --> id_2_check='4717' --> GM04717
# Patients_Catalog: match id='1650' --> id_2_check='1650' --> GM01650
# Patients_Catalog: match id='4819' --> id_2_check='4819' --> GM04819
# Patients_Catalog: match original_ID='848' --> id='0848' --> id_2_check='0848' --> NA0848
# Patients_Catalog: match id='4200' --> id_2_check='4200' --> GM04200
# Patients_Catalog: match id='4719' --> id_2_check='4719' --> GM04719
# Patients_Catalog: match id='1653' --> id_2_check='1653' --> GM01653
# Patients_Catalog: match id='4721' --> id_2_check='4721' --> GM04721
# Patients_Catalog: match id='4287' --> id_2_check='4287' --> GM04287
# Patient_ID
# NA0848     12
# GM04717     6
# GM01650     6
# GM04819     6
# GM04200     6
# GM04719     6
# GM01653     6
# GM04721     6
# GM04287     6
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp6  05.02.23__2023-02-19T12_14_21-Measurement 1.csv
# Patients_Catalog: match id='4689' --> id_2_check='4689' --> GM04689
# Patients_Catalog: match id='1650' --> id_2_check='1650' --> GM01650
# Patients_Catalog: match id='4715' --> id_2_check='4715' --> GM04715
# Patients_Catalog: match id='1653' --> id_2_check='1653' --> GM01653
# Patients_Catalog: match original_ID='305' --> id='0305' --> id_2_check='0305' --> GM00305
# Patients_Catalog: match original_ID='143' --> id='0143' --> id_2_check='0143' --> NA0143
# Patients_Catalog: match id='4717' --> id_2_check='4717' --> GM04717
# Patients_Catalog: match original_ID='495' --> id='0495' --> id_2_check='0495' --> NA0495
# Patients_Catalog: match id='4887' --> id_2_check='4887' --> GM04887
# Patients_Catalog: match id='4687' --> id_2_check='4687' --> GM04687
# Patient_ID
# GM04689    5
# GM01650    5
# GM01653    5
# GM00305    5
# NA0143     5
# GM04717    5
# GM04887    5
# NA0495     5
# GM04687    5
# GM04715    4
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp7 06.02.23__2023-02-19T14_31_42-Measurement 1.csv
# Patients_Catalog: match id='4693' --> id_2_check='4693' --> GM04693
# Patients_Catalog: match id='1650' --> id_2_check='1650' --> GM01650
# Patients_Catalog: match id='4799' --> id_2_check='4799' --> GM04799
# Patients_Catalog: match id='1653' --> id_2_check='1653' --> GM01653
# Patients_Catalog: match id='4807' --> id_2_check='4807' --> GM04807
# Patients_Catalog: match original_ID='730' --> id='0730' --> id_2_check='0730' --> NA0730
# Patients_Catalog: match id='4837' --> id_2_check='4837' --> GM04837
# Patients_Catalog: match original_ID='848' --> id='0848' --> id_2_check='0848' --> NA0848
# Patients_Catalog: match id='4212' --> id_2_check='4212' --> GM04212
# Patients_Catalog: match id='4709' --> id_2_check='4709' --> GM04709
# Patient_ID
# GM04693    6
# GM01650    6
# GM04799    6
# GM01653    6
# GM04807    6
# NA0730     6
# NA0848     6
# GM04212    6
# GM04709    6
# GM04837    5
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp8 12.02.23__2023-02-20T14_52_23-Measurement 1.csv
# Patients_Catalog: match id='2165' --> id_2_check='2165' --> GM02165
# Patients_Catalog: match id='1016' --> id_2_check='1016' --> NA1016
# Patients_Catalog: match id='4196' --> id_2_check='4196' --> GM04196
# Patients_Catalog: match original_ID='951' --> id='0951' --> id_2_check='0951' --> NA0951
# Patients_Catalog: match id='4476' --> id_2_check='4476' --> GM04476
# Patients_Catalog: match id='1170' --> id_2_check='1170' --> NA1170
# Patients_Catalog: match original_ID='848' --> id='0848' --> id_2_check='0848' --> NA0848
# Patient_ID
# GM02165    12
# GM04196    12
# GM04476    12
# NA1016      6
# NA0951      6
# NA1170      6
# NA0848      6
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- R exp4 05.07.22__2022-07-17T09_42_44-Measurement 1.csv
# Patients_Catalog: match id='4837' --> id_2_check='4837' --> GM04837
# Patients_Catalog: match id='1170' --> id_2_check='1170' --> NA1170
# Patients_Catalog: match id='4693' --> id_2_check='4693' --> GM04693
# Patients_Catalog: match id='1653' --> id_2_check='1653' --> GM01653
# Patients_Catalog: match id='4847' --> id_2_check='4847' --> GM04847
# Patients_Catalog: match id='4689' --> id_2_check='4689' --> GM04689
# Patients_Catalog: match original_ID='305' --> id='0305' --> id_2_check='0305' --> GM00305
# Patients_Catalog: match original_ID='495' --> id='0495' --> id_2_check='0495' --> NA0495
# Patients_Catalog: match id='2165' --> id_2_check='2165' --> GM02165
# Patients_Catalog: match original_ID='971' --> id='0971' --> id_2_check='0971' --> NA0971
# Patient_ID
# GM04837    6
# NA1170     6
# GM04693    6
# GM01653    6
# GM04847    6
# GM04689    6
# GM00305    6
# GM02165    6
# NA0495     3
# NA0971     3
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- S exp4 05.07.22 (9-10)__2022-07-12T11_44_17-Measurement 1.csv
# Patients_Catalog: match id='4767' --> id_2_check='4767' --> GM04767
# Patients_Catalog: match id='4285' --> id_2_check='4285' --> GM04285
# Patient_ID
# GM04285    6
# GM04767    2
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- S exp4 05.07.22__2022-07-12T10_09_44-Measurement 1.csv
# Patients_Catalog: match id='4687' --> id_2_check='4687' --> GM04687
# Patients_Catalog: match id='1650' --> id_2_check='1650' --> GM01650
# Patients_Catalog: match id='4691' --> id_2_check='4691' --> GM04691
# Patients_Catalog: match id='1170' --> id_2_check='1170' --> NA1170
# Patients_Catalog: match id='4849' --> id_2_check='4849' --> GM04849
# Patients_Catalog: match id='4807' --> id_2_check='4807' --> GM04807
# Patients_Catalog: match original_ID='848' --> id='0848' --> id_2_check='0848' --> NA0848
# Patients_Catalog: match id='4767' --> id_2_check='4767' --> GM04767
# Patients_Catalog: match id='1653' --> id_2_check='1653' --> GM01653
# Patients_Catalog: match original_ID='143' --> id='0143' --> id_2_check='0143' --> NA0143
# Patient_ID
# GM04687    6
# GM04691    6
# GM04849    6
# NA1170     6
# GM04807    6
# GM04767    4
# GM01650    3
# NA0848     3
# GM01653    3
# NA0143     3
# Name: Num_Wells, dtype: int64

# %%
DataFileLatB = Migration_Data(file_name_DataFileLatB, verbose=2)
# Out:
# Reading Migration_Data: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileLatB.csv
# Patients_Catalog: match id='AG01512' --> id_2_check='AG015' --> catalog_id_2_check='AG015' --> AG0015
# Patients_Catalog: match id='NA07309' --> id_2_check='NA0730' --> NA0730
# Patients_Catalog: match id='NA08788' --> id_2_check='NA0878' --> NA0878
# Patients_Catalog: match id='AG01512' --> id_2_check='AG015' --> catalog_id_2_check='AG015' --> AG0015
# Patients_Catalog: match id='NA07309' --> id_2_check='NA0730' --> NA0730
# Patients_Catalog: match id='NA08788' --> id_2_check='NA0878' --> NA0878
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0481913' --> id_2_check='GM04819' --> GM04819
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0481913' --> id_2_check='GM04819' --> GM04819
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0481913' --> id_2_check='GM04819' --> GM04819
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0481913' --> id_2_check='GM04819' --> GM04819
# CAPPatient
# 0'HC - AG01512               AG0015
# 0'HC - NA07309               NA0730
# 0'HC - NA08788               NA0878
# 0'HCMedia - AG01512          AG0015
# 0'HCMedia - NA07309          NA0730
# 0'HCMedia - NA08788          NA0878
# 100'HD - GM0421211          GM04212
# 96'HD - GM0481913           GM04819
# 100'HDMedia - GM0421211     GM04212
# 96'HDMedia - GM0481913      GM04819
# 100'LatBHigh - GM0421211    GM04212
# 96'LatBHigh - GM0481913     GM04819
# 100'LatBLow - GM0421211     GM04212
# 96'LatBLow - GM0481913      GM04819
# Name: Patient_ID, dtype: object
# Patient_ID
# AG0015     4
# NA0730     4
# NA0878     4
# GM04212    1
# GM04819    1
# Name: Num_Wells, dtype: int64

# %%
DataFileMitoQ = Migration_Data(file_name_DataFileMitoQ, verbose=2)
# Out:
# Reading Migration_Data: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileMitoQ.csv
# Patients_Catalog: match id='NA01438' --> id_2_check='NA0143' --> NA0143
# Patients_Catalog: match id='NA07309' --> id_2_check='NA0730' --> NA0730
# Patients_Catalog: match id='NA01438' --> id_2_check='NA0143' --> NA0143
# Patients_Catalog: match id='NA07309' --> id_2_check='NA0730' --> NA0730
# Patients_Catalog: match id='GM041968' --> id_2_check='GM04196' --> GM04196
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0471511' --> id_2_check='GM04715' --> GM04715
# Patients_Catalog: match id='GM041968' --> id_2_check='GM04196' --> GM04196
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0471511' --> id_2_check='GM04715' --> GM04715
# Patients_Catalog: match id='GM041968' --> id_2_check='GM04196' --> GM04196
# Patients_Catalog: match id='GM0421211' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match id='GM0471511' --> id_2_check='GM04715' --> GM04715
# Patients_Catalog: extact match id='GM01653'
# Patients_Catalog: extact match id='NA0971'
# Patients_Catalog: extact match id='NA1170'
# Patients_Catalog: extact match id='GM00305'
# Patients_Catalog: extact match id='GM02165'
# Patients_Catalog: extact match id='GM04847'
# Patients_Catalog: extact match id='GM04689'
# Patients_Catalog: extact match id='GM04693'
# Patients_Catalog: extact match id='GM04837'
# Patients_Catalog: extact match id='GM04847'
# Patients_Catalog: extact match id='GM00305'
# Patients_Catalog: extact match id='GM02165'
# Patients_Catalog: extact match id='GM04689'
# Patients_Catalog: extact match id='GM04693'
# Patients_Catalog: extact match id='GM04837'
# Patients_Catalog: extact match id='NA0143'
# Patients_Catalog: extact match id='GM04285'
# Patients_Catalog: extact match id='GM04687'
# Patients_Catalog: extact match id='GM04691'
# Patients_Catalog: extact match id='GM04767'
# Patients_Catalog: extact match id='GM04807'
# Patients_Catalog: extact match id='GM04849'
# Patients_Catalog: extact match id='GM04285'
# Patients_Catalog: extact match id='GM04687'
# Patients_Catalog: extact match id='GM04691'
# Patients_Catalog: extact match id='GM04767'
# Patients_Catalog: extact match id='GM04807'
# Patients_Catalog: extact match id='GM04849'
# CAPPatient
# 0'HC - NA01438              NA0143
# 0'HC - NA07309              NA0730
# 0'HCMedia - NA01438         NA0143
# 0'HCMedia - NA07309         NA0730
# 110'HD - GM041968          GM04196
# 100'HD - GM0421211         GM04212
# 111'HD - GM0471511         GM04715
# 110'HDMedia - GM041968     GM04196
# 100'HDMedia - GM0421211    GM04212
# 111'HDMedia - GM0471511    GM04715
# 110'MitoQ - GM041968       GM04196
# 100'MitoQ - GM0421211      GM04212
# 111'MitoQ - GM0471511      GM04715
# 0'HC - GM01653             GM01653
# 0'HC - NA0971               NA0971
# 0'HC - NA1170               NA1170
# 129'HD - GM00305           GM00305
# 141'HD - GM02165           GM02165
# 76'MitoQ - GM04847         GM04847
# 69'HD - GM04689            GM04689
# 76'HD - GM04693            GM04693
# 60'HD - GM04837            GM04837
# 76'HD - GM04847            GM04847
# 129'MitoQ - GM00305        GM00305
# 141'MitoQ - GM02165        GM02165
# 69'MitoQ - GM04689         GM04689
# 76'MitoQ - GM04693         GM04693
# 60'MitoQ - GM04837         GM04837
# 0'HC - NA0143               NA0143
# 129'HD - GM04285           GM04285
# 114'HD - GM04687           GM04687
# 115'HD - GM04691           GM04691
# 106'HD - GM04767           GM04767
# 126'HD - GM04807           GM04807
# 104'HD - GM04849           GM04849
# 129'MitoQ - GM04285        GM04285
# 114'MitoQ - GM04687        GM04687
# 115'MitoQ - GM04691        GM04691
# 106'MitoQ - GM04767        GM04767
# 126'MitoQ - GM04807        GM04807
# 104'MitoQ - GM04849        GM04849
# Name: Patient_ID, dtype: object
# Patient_ID
# NA0143      5
# NA0730      2
# GM04196     2
# GM04212     3
# GM04715     2
# GM01653     8
# NA0971      6
# NA1170     11
# GM00305     2
# GM02165     2
# GM04847     2
# GM04689     2
# GM04693     2
# GM04837     3
# GM04285     1
# GM04687     1
# GM04691     3
# GM04767     3
# GM04807     2
# GM04849     2
# Name: Num_Wells, dtype: int64

# %%
DataFileWithHGPS = Migration_Data(file_name_DataFileWithHGPS, verbose=2)
# Out:
# Reading Migration_Data: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileWithHGPS.csv
# Patients_Catalog: match id='NA014310' --> id_2_check='NA0143' --> NA0143
# Patients_Catalog: match id='NA049513' --> id_2_check='NA0495' --> NA0495
# Patients_Catalog: match id='NA084813' --> id_2_check='NA0848' --> NA0848
# Patients_Catalog: match id='NA097110' --> id_2_check='NA0971' --> NA0971
# Patients_Catalog: match id='NA117014' --> id_2_check='NA1170' --> NA1170
# Patients_Catalog: match original_ID='NA0165017' --> id='GM0165017' --> id_2_check='GM01650' --> GM01650
# Patients_Catalog: match original_ID='NA0165320' --> id='GM0165320' --> id_2_check='GM01653' --> GM01653
# Patients_Catalog: match original_ID='NA4614610' --> id='AG1614610' --> id_2_check='AG16146' --> AG16146
# Patients_Catalog: match original_ID='NAIC016' --> id='NA0016' --> id_2_check='NA001' --> catalog_id_2_check='NA00143' --> NA0143
# Patients_Catalog: match original_ID='NAIC025' --> id='NA0025'
# Patients_Catalog: match original_ID='NAIC143' --> id='NA0143'
# Patients_Catalog: match original_ID='NAIC157' --> id='NA0157'
# Patients_Catalog: match original_ID='NAIC170' --> id='NA0170' --> id_2_check='NA01' --> NA0143
# Patients_Catalog: match original_ID='NAIC233' --> id='NA0233'
# Patients_Catalog: match original_ID='NAIC234' --> id='NA0234'
# Patients_Catalog: match original_ID='NAIC477' --> id='NA0477'
# Patients_Catalog: match original_ID='NAIC561' --> id='NA0561'
# Patients_Catalog: match original_ID='NAIC579' --> id='NA0579'
# Patients_Catalog: match original_ID='NAIC633' --> id='NA0633'
# Patients_Catalog: match original_ID='NAIC769' --> id='NA0769'
# Patients_Catalog: match original_ID='NAIC878' --> id='NA0878'
# Patients_Catalog: match id='GM0468911' --> id_2_check='GM04689' --> GM04689
# Patients_Catalog: match id='GM0469309' --> id_2_check='GM04693' --> GM04693
# Patients_Catalog: match id='GM0483713' --> id_2_check='GM04837' --> GM04837
# Patients_Catalog: match id='GM0484714' --> id_2_check='GM04847' --> GM04847
# Patients_Catalog: match original_ID='GMIC4717' --> id='GM04717'
# Patients_Catalog: match original_ID='GMIC4719' --> id='GM04719'
# Patients_Catalog: match original_ID='GM04484909' --> id='GM0484909' --> id_2_check='GM04849' --> GM04849
# Patients_Catalog: match id='GM0469109' --> id_2_check='GM04691' --> GM04691
# Patients_Catalog: match id='GM0476713' --> id_2_check='GM04767' --> GM04767
# Patients_Catalog: match original_ID='GM0568716' --> id='GM0468716' --> id_2_check='GM04687' --> GM04687
# Patients_Catalog: match original_ID='GMIC214712' --> id='GM0214712' --> id_2_check='GM02147' --> GM02147
# Patients_Catalog: match original_ID='GMIC41968' --> id='GM041968' --> id_2_check='GM04196' --> GM04196
# Patients_Catalog: match original_ID='GMIC42128' --> id='GM042128' --> id_2_check='GM04212' --> GM04212
# Patients_Catalog: match original_ID='GMIC4709' --> id='GM04709'
# Patients_Catalog: match original_ID='GMIC4715' --> id='GM04715'
# Patients_Catalog: match original_ID='GMIC4721' --> id='GM04721'
# Patients_Catalog: match original_ID='GMIC47997' --> id='GM047997' --> id_2_check='GM04799' --> GM04799
# Patients_Catalog: match original_ID='GMIC48198' --> id='GM048198' --> id_2_check='GM04819' --> GM04819
# Patients_Catalog: match original_ID='GMIC48878' --> id='GM048878' --> id_2_check='GM04887' --> GM04887
# Patients_Catalog: match id='GM0030518' --> id_2_check='GM00305' --> GM00305
# Patients_Catalog: match id='GM0216516' --> id_2_check='GM02165' --> GM02165
# Patients_Catalog: match id='GM0428510' --> id_2_check='GM04285' --> GM04285
# Patients_Catalog: match original_ID='GM04484715' --> id='GM0484715' --> id_2_check='GM04847' --> GM04847
# Patients_Catalog: match original_ID='GMIC4200' --> id='GM04200'
# Patients_Catalog: match original_ID='GMIC4287' --> id='GM04287'
# Patients_Catalog: match original_ID='GMIC447610' --> id='GM0447610' --> id_2_check='GM04476' --> GM04476
# Patients_Catalog: match original_ID='GMIC5031' --> id='GM05031'
# Patients_Catalog: match original_ID='GMIC62748' --> id='GM062748' --> id_2_check='GM06274' --> GM06274
# Patients_Catalog: match original_ID='pro18816' --> id='HGADFN18816' --> id_2_check='HGADFN188' --> catalog_id_2_check='HGADFN188' --> HGADFN0188
# Patients_Catalog: match original_ID='pro27113' --> id='HGADFN27113' --> id_2_check='HGADFN271' --> catalog_id_2_check='HGADFN271' --> HGADFN0271
# Patients_Catalog: match original_ID='pro36713' --> id='HGADFN36713' --> id_2_check='HGADFN367' --> catalog_id_2_check='HGADFN367' --> HGADFN0367
# Patients_Catalog: match original_ID='pro12218' --> id='HGADFN12218' --> id_2_check='HGADFN122' --> catalog_id_2_check='HGADFN122' --> HGADFN0122
# Patients_Catalog: match original_ID='pro12716' --> id='HGADFN12716' --> id_2_check='HGADFN127' --> catalog_id_2_check='HGADFN127' --> HGADFN0127
# Patients_Catalog: match original_ID='pro16915' --> id='HGADFN16915' --> id_2_check='HGADFN169' --> catalog_id_2_check='HGADFN169' --> HGADFN0169
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=NA0165017 --> selected_id='GM0165017' --> ret_id='GM01650'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=NA0165320 --> selected_id='GM0165320' --> ret_id='GM01653'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=NA4614610 --> selected_id='AG1614610' --> ret_id='AG16146'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=GM04484909 --> selected_id='GM0484909' --> ret_id='GM04849'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=GM0568716 --> selected_id='GM0468716' --> ret_id='GM04687'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Patients_Catalog.py:55: UserWarning: Found typo!! base_id=GM04484715 --> selected_id='GM0484715' --> ret_id='GM04847'
#   warnings.warn(str_warn)
# d:\projects\BioTAU\Huntington\python\Migration_Data.py:43: UserWarning: cap_patient="126'GM04484715" --> patient_id='GM04847'  -> catalog_cap=np.float32(76.43)
#   warnings.warn(f'{cap_patient=} --> {patient_id=}  -> {catalog_cap=}')
# CAPPatient
# 0'NA014310            NA0143
# 0'NA049513            NA0495
# 0'NA084813            NA0848
# 0'NA097110            NA0971
# 0'NA117014            NA1170
# 0'NA0165017          GM01650
# 0'NA0165320          GM01653
# 0'NA4614610          AG16146
# 0'NAIC016             NA0143
# 0'NAIC025             NA0025
# 0'NAIC143             NA0143
# 0'NAIC157             NA0157
# 0'NAIC170             NA0143
# 0'NAIC233             NA0233
# 0'NAIC234             NA0234
# 0'NAIC477             NA0477
# 0'NAIC561             NA0561
# 0'NAIC579             NA0579
# 0'NAIC633             NA0633
# 0'NAIC769             NA0769
# 0'NAIC878             NA0878
# 69'GM0468911         GM04689
# 76'GM0469309         GM04693
# 60'GM0483713         GM04837
# 76'GM0484714         GM04847
# 75'GMIC4717          GM04717
# 84'GMIC4719          GM04719
# 104'GM04484909       GM04849
# 115'GM0469109        GM04691
# 106'GM0476713        GM04767
# 114'GM0568716        GM04687
# 119'GMIC214712       GM02147
# 110'GMIC41968        GM04196
# 100'GMIC42128        GM04212
# 111'GMIC4709         GM04709
# 111'GMIC4715         GM04715
# 91'GMIC4721          GM04721
# 94'GMIC47997         GM04799
# 96'GMIC48198         GM04819
# 111'GMIC48878        GM04887
# 129'GM0030518        GM00305
# 141'GM0216516        GM02165
# 129'GM0428510        GM04285
# 126'GM04484715       GM04847
# 131'GMIC4200         GM04200
# 126'GMIC4287         GM04287
# 132'GMIC447610       GM04476
# 139'GMIC5031         GM05031
# 129'GMIC62748        GM06274
# 999'pro18816      HGADFN0188
# 999'pro27113      HGADFN0271
# 999'pro36713      HGADFN0367
# 999'pro12218      HGADFN0122
# 999'pro12716      HGADFN0127
# 999'pro16915      HGADFN0169
# Name: Patient_ID, dtype: object
# Patient_ID
# NA0143         1
# NA0495         6
# NA0848         3
# NA0971         6
# NA1170        18
# GM01650        3
# GM01653        9
# AG16146        6
# NA0025         1
# NA0157         1
# NA0233         1
# NA0234         1
# NA0477         1
# NA0561         1
# NA0579         1
# NA0633         1
# NA0769         1
# NA0878         1
# GM04689       12
# GM04693       12
# GM04837       12
# GM04847        6
# GM04717        1
# GM04719        1
# GM04849        6
# GM04691        6
# GM04767        6
# GM04687        6
# GM02147        1
# GM04196        1
# GM04212        1
# GM04709        1
# GM04715        1
# GM04721        1
# GM04799        1
# GM04819        1
# GM04887        1
# GM00305       12
# GM02165       11
# GM04285        6
# GM04200        1
# GM04287        1
# GM04476        1
# GM05031        1
# GM06274        1
# HGADFN0188     6
# HGADFN0271     6
# HGADFN0367     6
# HGADFN0122     6
# HGADFN0127     6
# HGADFN0169     6
# Name: Num_Wells, dtype: int64
