# %% [markdown]
# ### Porting to Google Colab
# The following cell enables this notebook to run from Google Colab as well as from your local machine IDE.<br>
# You can change `root_directory` and/or `this_notebook_google_path` to point to the directory in your Google account, which contains this notebook, together with the `imgs` sub-directory and the rest of the files.<br>

# %%
import sys
import os
try:
    from google.colab import drive as google_drive
except:
    # no Google Colab --> fall back to local machine
    google_drive = None

if google_drive is not None:
    google_drive_directory = os.path.join('/','content','gdrive')
    google_drive.mount(google_drive_directory)
    all_projects_path = os.path.join(google_drive_directory, 'Othercomputers','My Laptop', 'projects')
else:
    all_projects_path = os.path.join('d:\\', 'projects')

project_path = os.path.join(all_projects_path,'BioTAU','Huntington')
assert os.path.exists(project_path), f'Path {project_path} not found!'
# enable import python files from this notebook's path
sys.path.append(project_path)
# enable reading images and data files from this notebook's path
os.chdir(project_path)

datasets_path = os.path.join(project_path, 'datasets')

print(f'Current working directory: {os.getcwd()}')
print(f'Datasets path: {datasets_path}')
# Out:
# Current working directory: d:\projects\BioTAU\Huntington
# Datasets path: d:\projects\BioTAU\Huntington\datasets

# %%
from python.Migration_Data import Migration_Data, HGPS_Plate_Results, HGPS_Data_APRW, LatB_LowHigh_MitoQ_APRW

# %%
file_name_DataFileLatB = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'Migration', 'DataFileLatB.csv')
file_name_DataFileMitoQ = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'Migration', 'DataFileMitoQ.csv')
file_name_DataFileWithHGPS = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'Migration', 'DataFileWithHGPS.csv')
file_name_HGPS_PlateResults = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'HGPS_PlateResults.csv')
file_name_HGPS_PlateResults_5 = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- exp5 plate1 08.01.23__2023-01-12T15_50_14-Measurement 1.csv')
file_name_HGPS_PlateResults_6 = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- exp6  05.02.23__2023-02-19T12_14_21-Measurement 1.csv')
file_name_HGPS_PlateResults_7 = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- exp7 06.02.23__2023-02-19T14_31_42-Measurement 1.csv')
file_name_HGPS_PlateResults_8 = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- exp8 12.02.23__2023-02-20T14_52_23-Measurement 1.csv')
file_name_HGPS_PlateResults_4R = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- R exp4 05.07.22__2022-07-17T09_42_44-Measurement 1.csv')
file_name_HGPS_PlateResults_4Sa = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- S exp4 05.07.22 (9-10)__2022-07-12T11_44_17-Measurement 1.csv')
file_name_HGPS_PlateResults_4Sb = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data_Excels', 'LaminB', 'PlateResults - LaminB+a actinin- S exp4 05.07.22__2022-07-12T10_09_44-Measurement 1.csv')
file_name_HGPS_Data_APRW_Model = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data', 'HGPS_Data', 'APRW Model Features Wells Created.csv')
file_name_LatB_LowHigh_APRW_Model = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data', 'LatB_LowHigh', 'APRW Model Features.csv')
file_name_MitoQ_APRW_Model = os.path.join(datasets_path, 'Cell_Migration', 'Migration_Data', 'MitoQ_Media_DMSO_Cleaned_75', 'APRW Model Features.csv')

# %% [markdown]
# # Read Migration Data

# %%
LatB_LowHigh_APRW_data = LatB_LowHigh_MitoQ_APRW(file_name=file_name_LatB_LowHigh_APRW_Model,verbose=2)
MitoQ_APRW_data = LatB_LowHigh_MitoQ_APRW(file_name=file_name_MitoQ_APRW_Model,verbose=2)
# Out:
# Reading LatB_LowHigh_MitoQ_APRW: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\LatB_LowHigh\APRW Model Features.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\LatB_LowHigh\APRW Model Features.csv into 4448 rows and 19 columns
# 1 Integers columns: ['CellID']
# 12 Float columns: ['CAPr', 'CAP', 'Pp', 'Sp', 'Pnp', 'Snp', 'Dp', 'Dnp', 'Dtot', 'Psi', 'MSD10', 'SP10']
# 6 Strings columns: ['CELLTYPE', 'Patient/CELLID2', 'Patient/CELLID3', 'Patient/CELLID', 'CAPPatient', 'CAPPatient2']
# Column: CELLTYPE, Data Type: object
# Column: CellID, Data Type: Int32
# Column: Patient/CELLID2, Data Type: object
# Column: Patient/CELLID3, Data Type: object
# Column: Patient/CELLID, Data Type: object
# Column: CAPr, Data Type: float32
# Column: CAP, Data Type: float32
# Column: CAPPatient, Data Type: object
# Column: CAPPatient2, Data Type: object
# Column: Pp, Data Type: float32
# Column: Sp, Data Type: float32
# Column: Pnp, Data Type: float32
# Column: Snp, Data Type: float32
# Column: Dp, Data Type: float32
# Column: Dnp, Data Type: float32
# Column: Dtot, Data Type: float32
# Column: Psi, Data Type: float32
# Column: MSD10, Data Type: float32
# Column: SP10, Data Type: float32
#   CELLTYPE  CellID     Patient/CELLID2 Patient/CELLID3 Patient/CELLID  CAPr  \
# 0     'HC'       1  'HC - AG01512_B21'   'HC - AG01512          0'HC'   0.0
# 1     'HC'       2  'HC - AG01512_B21'   'HC - AG01512          0'HC'   0.0
# 2     'HC'       3  'HC - AG01512_B21'   'HC - AG01512          0'HC'   0.0
# 3     'HC'       4  'HC - AG01512_B21'   'HC - AG01512          0'HC'   0.0
# 4     'HC'       5  'HC - AG01512_B21'   'HC - AG01512          0'HC'   0.0
#
#    CAP      CAPPatient          CAPPatient2        Pp       Sp      Pnp  \
# 0  0.0  0'HC - AG01512  0'HC - AG01512_B21'    0.9321   1.1405   0.8113
# 1  0.0  0'HC - AG01512  0'HC - AG01512_B21'    0.0193  19.9997   0.9522
# 2  0.0  0'HC - AG01512  0'HC - AG01512_B21'    0.9552   1.6021  48.0389
# 3  0.0  0'HC - AG01512  0'HC - AG01512_B21'    0.9676   5.3112   2.4787
# 4  0.0  0'HC - AG01512  0'HC - AG01512_B21'  999.9994   0.1094  53.0264
#
#       Snp      Dp     Dnp    Dtot      Psi       MSD10     SP10
# 0  0.5174  0.3031  0.0543  0.3574   5.5823    769.1829   2.7734
# 1  1.5973  1.9282  0.6074  2.5356   3.1745   1337.5328   3.6572
# 2  0.0840  0.6129  0.0848  0.6977   7.2286    529.5131   2.3011
# 3  1.8639  6.8234  2.1528  8.9763   3.1695  14568.6602  12.0701
# 4  0.0954  2.9912  0.1206  3.1119  24.7963   1094.2180   3.3079
# Patient_ID
# AG0015     4
# NA0730     4
# NA0878     4
# GM04212    1
# GM04819    1
# Name: Num_Wells, dtype: int64
# Reading LatB_LowHigh_MitoQ_APRW: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\MitoQ_Media_DMSO_Cleaned_75\APRW Model Features.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\MitoQ_Media_DMSO_Cleaned_75\APRW Model Features.csv into 20050 rows and 19 columns
# 1 Integers columns: ['CellID']
# 12 Float columns: ['CAPr', 'CAP', 'Pp', 'Sp', 'Pnp', 'Snp', 'Dp', 'Dnp', 'Dtot', 'Psi', 'MSD10', 'SP10']
# 6 Strings columns: ['CELLTYPE', 'Patient/CELLID2', 'Patient/CELLID3', 'Patient/CELLID', 'CAPPatient', 'CAPPatient2']
# Column: CELLTYPE, Data Type: object
# Column: CellID, Data Type: Int32
# Column: Patient/CELLID2, Data Type: object
# Column: Patient/CELLID3, Data Type: object
# Column: Patient/CELLID, Data Type: object
# Column: CAPr, Data Type: float32
# Column: CAP, Data Type: float32
# Column: CAPPatient, Data Type: object
# Column: CAPPatient2, Data Type: object
# Column: Pp, Data Type: float32
# Column: Sp, Data Type: float32
# Column: Pnp, Data Type: float32
# Column: Snp, Data Type: float32
# Column: Dp, Data Type: float32
# Column: Dnp, Data Type: float32
# Column: Dtot, Data Type: float32
# Column: Psi, Data Type: float32
# Column: MSD10, Data Type: float32
# Column: SP10, Data Type: float32
#   CELLTYPE  CellID    Patient/CELLID2 Patient/CELLID3 Patient/CELLID  CAPr  \
# 0     'HC'       1  'HC - NA01438_C4'   'HC - NA01438          0'HC'   0.0
# 1     'HC'       2  'HC - NA01438_C4'   'HC - NA01438          0'HC'   0.0
# 2     'HC'       3  'HC - NA01438_C4'   'HC - NA01438          0'HC'   0.0
# 3     'HC'       4  'HC - NA01438_C4'   'HC - NA01438          0'HC'   0.0
# 4     'HC'       5  'HC - NA01438_C4'   'HC - NA01438          0'HC'   0.0
#
#    CAP      CAPPatient         CAPPatient2       Pp      Sp      Pnp     Snp  \
# 0  0.0  0'HC - NA01438  0'HC - NA01438_C4'  37.9020  0.4441  18.1948  0.1952
# 1  0.0  0'HC - NA01438  0'HC - NA01438_C4'  84.2215  0.3910  15.7286  0.2442
# 2  0.0  0'HC - NA01438  0'HC - NA01438_C4'  75.4571  0.3588  62.9828  0.2635
# 3  0.0  0'HC - NA01438  0'HC - NA01438_C4'   0.9081  2.6975   0.8196  0.2744
# 4  0.0  0'HC - NA01438  0'HC - NA01438_C4'   0.9147  0.6159   0.8835  0.6231
#
#        Dp     Dnp    Dtot       Psi      MSD10    SP10
# 0  1.8692  0.1732  2.0424   10.7895  6782.1699  8.2354
# 1  3.2182  0.2344  3.4527   13.7277  6696.9766  8.1835
# 2  2.4281  1.0935  3.5216    2.2205  8291.3057  9.1057
# 3  1.6518  0.0154  1.6673  107.0947  1211.2532  3.4803
# 4  0.0867  0.0857  0.1725    1.0117   157.8486  1.2564
# Patient_ID
# NA0143      5
# NA0730      2
# GM04196     2
# GM04212     3
# GM04715     2
# GM01653     8
# NA0971      6
# NA1170     11
# GM00305     2
# GM02165     2
# GM04847     2
# GM04689     2
# GM04693     2
# GM04837     3
# GM04285     1
# GM04687     1
# GM04691     3
# GM04767     3
# GM04807     2
# GM04849     2
# Name: Num_Wells, dtype: int64

# %%
HGPS_data_APRW = HGPS_Data_APRW(file_name=file_name_HGPS_Data_APRW_Model,verbose=2)
# Out:
# Reading HGPS_Data_APRW: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\HGPS_Data\APRW Model Features Wells Created.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data\HGPS_Data\APRW Model Features Wells Created.csv into 227 rows and 18 columns
# 1 Integers columns: ['CellID']
# 11 Float columns: ['CAP', 'Pp', 'Sp', 'Pnp', 'Snp', 'Dp', 'Dnp', 'Dtot', 'Psi', 'MSD10', 'SP10']
# 6 Strings columns: ['CELLTYPE', 'Patient/CELLID2', 'Patient/CELLID3', 'Patient/CELLID', 'CAPPatient', 'CAPPatient2']
# Column: CELLTYPE, Data Type: object
# Column: CellID, Data Type: Int32
# Column: Patient/CELLID2, Data Type: object
# Column: Patient/CELLID3, Data Type: object
# Column: Patient/CELLID, Data Type: object
# Column: CAP, Data Type: float32
# Column: CAPPatient, Data Type: object
# Column: CAPPatient2, Data Type: object
# Column: Pp, Data Type: float32
# Column: Sp, Data Type: float32
# Column: Pnp, Data Type: float32
# Column: Snp, Data Type: float32
# Column: Dp, Data Type: float32
# Column: Dnp, Data Type: float32
# Column: Dtot, Data Type: float32
# Column: Psi, Data Type: float32
# Column: MSD10, Data Type: float32
# Column: SP10, Data Type: float32
#   CELLTYPE  CellID   Patient/CELLID2 Patient/CELLID3 Patient/CELLID  CAP  \
# 0     'HC'       1   'NA014310_E8_1'       'NA014310          0'HC'  0.0
# 1     'HC'       2   'NA014310_F8_1'       'NA014310          0'HC'  0.0
# 2     'HC'       3   'NA014310_G8_1'       'NA014310          0'HC'  0.0
# 3     'HC'       4  'NA0165017_B3_1'      'NA0165017          0'HC'  0.0
# 4     'HC'       5  'NA0165017_C3_1'      'NA0165017          0'HC'  0.0
#
#     CAPPatient        CAPPatient2       Pp      Sp      Pnp     Snp      Dp  \
# 0   0'NA014310   0'NA014310_E8_1'  40.2799  1.2321  31.0842  0.6589  1.8205
# 1   0'NA014310   0'NA014310_F8_1'  32.8514  1.2080  25.6981  0.5474  1.4695
# 2   0'NA014310   0'NA014310_G8_1'  17.7772  1.1411  31.3943  0.5594  1.3788
# 3  0'NA0165017  0'NA0165017_B3_1'  78.3268  0.9623  29.3497  0.5160  1.5598
# 4  0'NA0165017  0'NA0165017_C3_1'  62.9811  0.7835  45.9051  0.4176  1.8350
#
#       Dnp    Dtot      Psi      MSD10    SP10
# 0  0.6733  2.4938   9.7813  3428.0488  5.2455
# 1  0.6078  2.0773  12.6321  3280.7764  4.9863
# 2  0.8673  2.2461   8.9783  2777.3091  4.6636
# 3  0.4427  2.0025  21.5107  2448.2251  4.3211
# 4  0.5508  2.3858  23.2409  3393.9836  5.1030
# Patient_ID
# NA1170        18
# GM04847       18
# GM00305       12
# GM04837       12
# GM04689       12
# GM04693       12
# GM02165       11
# GM01653        9
# AG16146        7
# GM04691        6
# NA0971         6
# HGADFN0127     6
# GM04767        6
# GM04849        6
# GM04285        6
# GM04687        6
# HGADFN0169     6
# HGADFN0188     6
# HGADFN0122     6
# NA0495         6
# HGADFN0367     6
# HGADFN0271     6
# NA0143         4
# GM01650        3
# NA0848         3
# NA0878         1
# NA0769         1
# NA0633         1
# NA0233         1
# NA0170         1
# NA0157         1
# NA0025         1
# NA0579         1
# NA0561         1
# NA0477         1
# NA0234         1
# GM04212        1
# GM04476        1
# GM06274        1
# GM04287        1
# GM02147        1
# GM04196        1
# GM04887        1
# GM04715        1
# GM04709        1
# GM04200        1
# GM04717        1
# GM05031        1
# GM04721        1
# GM04719        1
# GM04799        1
# GM04819        1
# Name: Num_Wells, dtype: int64

# %%
HGPS_Results = HGPS_Plate_Results(file_name=file_name_HGPS_PlateResults, verbose=2)
HGPS_PlateResults_5 = HGPS_Plate_Results(file_name_HGPS_PlateResults_5, verbose=2)
HGPS_PlateResults_6 = HGPS_Plate_Results(file_name_HGPS_PlateResults_6, verbose=2)
HGPS_PlateResults_7 = HGPS_Plate_Results(file_name_HGPS_PlateResults_7, verbose=2)
HGPS_PlateResults_8 = HGPS_Plate_Results(file_name_HGPS_PlateResults_8, verbose=2)
HGPS_PlateResults_4R = HGPS_Plate_Results(file_name_HGPS_PlateResults_4R, verbose=2)
HGPS_PlateResults_4Sa = HGPS_Plate_Results(file_name_HGPS_PlateResults_4Sa, verbose=2)
HGPS_PlateResults_4Sb = HGPS_Plate_Results(file_name_HGPS_PlateResults_4Sb, verbose=2)
# Out:
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\HGPS_PlateResults.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\HGPS_PlateResults.csv into 61 rows and 51 columns
# 12 Integers columns: ['Row', 'Column', 'Plane', 'Timepoint', 'all_cells_Number_of_Objects', 'all_cells_chanel_3_Intensity_Sum_Sum_per_Well', 'all_cells_chanel_4_Intensity_Sum_Sum_per_Well', 'Number_of_Analyzed_Fields', 'Height_[µm]', 'Time_[s]', 'CAP', 'Cell_ID']
# 38 Float columns: ['modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well', 'modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well', 'spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Contrast_Mean_per_Well', 'spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well', 'spots_chanel_3_final_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well', 'modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_3_Intensity_Mean_Mean_per_Well', 'all_cells_chanel_2_Area_[µm²]_Mean_per_Well', 'all_cells_Intensity_chanel_2_Mean_Mean_per_Well', 'all_cells_chanel_1_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well', 'all_cells_Intensity_chanel_1_Mean_Mean_per_Well', 'all_cells_chanel_4_Intensity_Mean_Mean_per_Well', 'all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well', 'ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well', 'ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well', 'ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well', 'total_ir_chanel_4_normalized', 'total_ir_chanel_3_normalized']
# 1 Strings columns: ['Cell_Type']
# Column: Row, Data Type: Int32
# Column: Column, Data Type: Int32
# Column: Plane, Data Type: Int32
# Column: Timepoint, Data Type: Int32
# Column: modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Contrast_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Number_of_Objects, Data Type: Int32
# Column: all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_chanel_2_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_2_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_1_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: total_ir_chanel_4_normalized, Data Type: float32
# Column: total_ir_chanel_3_normalized, Data Type: float32
# Column: Number_of_Analyzed_Fields, Data Type: Int32
# Column: Height_[µm], Data Type: Int32
# Column: Time_[s], Data Type: Int32
# Column: Cell_Type, Data Type: object
# Column: CAP, Data Type: Int32
# Column: Cell_ID, Data Type: Int32
#    Row  Column  Plane  Timepoint  \
# 0    2       2      1          0
# 1    2       3      1          0
# 2    2       4      1          0
# 3    2       5      1          0
# 4    2       6      1          0
#
#    modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well  \
# 0                                                 5.7340
# 1                                                 5.6457
# 2                                                 6.3554
# 3                                                 5.6897
# 4                                                 6.9055
#
#    modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                         0.5864
# 1                                                         0.5882
# 2                                                         0.5893
# 3                                                         0.5788
# 4                                                         0.6134
#
#    modified_spots_chanel_3_Number_of_Spots_Mean_per_Well  \
# 0                                                 0.9725
# 1                                                 0.9715
# 2                                                 1.0042
# 3                                                 0.9768
# 4                                                 1.0373
#
#    modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well  \
# 0                                                                                     0.1849
# 1                                                                                     0.1870
# 2                                                                                     0.1788
# 3                                                                                     0.1877
# 4                                                                                     0.1725
#
#    spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                      0.7166
# 1                                                      0.7146
# 2                                                      0.7208
# 3                                                      0.7075
# 4                                                      0.7307
#
#    spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well  ...  \
# 0                                                      31.6829  ...
# 1                                                      31.0723  ...
# 2                                                      32.9967  ...
# 3                                                      29.3088  ...
# 4                                                      35.7368  ...
#
#    ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well  \
# 0                                                   70248.5547
# 1                                                   78219.1797
# 2                                                   38283.6484
# 3                                                   44529.6406
# 4                                                    7958.3013
#
#    ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well  \
# 0                                                  880538.7500
# 1                                                  888743.8750
# 2                                                  265046.5312
# 3                                                  342978.1562
# 4                                                  144518.7969
#
#    total_ir_chanel_4_normalized  total_ir_chanel_3_normalized  \
# 0                       84.2309                     1055.8019
# 1                       92.4577                     1050.5247
# 2                      127.1882                      880.5532
# 3                      108.0817                      832.4713
# 4                       89.4191                     1623.8066
#
#    Number_of_Analyzed_Fields  Height_[µm]  Time_[s]  Cell_Type  CAP  Cell_ID
# 0                         35            0         0       HGPS  999    12213
# 1                         35            0         0       HGPS  999    12213
# 2                         34            0         0         HC    0       16
# 3                         34            0         0         HC    0       16
# 4                         31            0         0       HGPS  999       13
#
# [5 rows x 51 columns]
# 12213 ['HGPS']
# 16 ['HC']
# 13 ['HGPS']
# 1514 ['HC']
# 12715 ['HGPS']
# Patients_Catalog: match 12715 --> HGADFN0127
# Patients_Catalog: match 0016 --> GM01650
# Patients_Catalog: match 1514 --> AG0015
# Patients_Catalog: match 12213 --> HGADFN0122
# Patients_Catalog: match 0013 --> HGADFN0013
# Patient_ID
# HGADFN0122    12
# GM01650       12
# HGADFN0013    12
# AG0015        12
# HGADFN0127    12
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp5 plate1 08.01.23__2023-01-12T15_50_14-Measurement 1.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp5 plate1 08.01.23__2023-01-12T15_50_14-Measurement 1.csv into 61 rows and 51 columns
# 11 Integers columns: ['Row', 'Column', 'Plane', 'Timepoint', 'all_cells_Number_of_Objects', 'all_cells_chanel_3_Intensity_Sum_Sum_per_Well', 'all_cells_chanel_4_Intensity_Sum_Sum_per_Well', 'Number_of_Analyzed_Fields', 'Height_[µm]', 'Time_[s]', 'Cell_ID']
# 39 Float columns: ['modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well', 'modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well', 'spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Contrast_Mean_per_Well', 'spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well', 'spots_chanel_3_final_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well', 'modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_3_Intensity_Mean_Mean_per_Well', 'all_cells_chanel_2_Area_[µm²]_Mean_per_Well', 'all_cells_Intensity_chanel_2_Mean_Mean_per_Well', 'all_cells_chanel_1_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well', 'all_cells_Intensity_chanel_1_Mean_Mean_per_Well', 'all_cells_chanel_4_Intensity_Mean_Mean_per_Well', 'all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well', 'ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well', 'ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well', 'ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well', 'total_ir_chanel_4_normalized', 'total_ir_chanel_3_normalized', 'CAP']
# 1 Strings columns: ['Cell_Type']
# Column: Row, Data Type: Int32
# Column: Column, Data Type: Int32
# Column: Plane, Data Type: Int32
# Column: Timepoint, Data Type: Int32
# Column: modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Contrast_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Number_of_Objects, Data Type: Int32
# Column: all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_chanel_2_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_2_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_1_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: total_ir_chanel_4_normalized, Data Type: float32
# Column: total_ir_chanel_3_normalized, Data Type: float32
# Column: Number_of_Analyzed_Fields, Data Type: Int32
# Column: Height_[µm], Data Type: Int32
# Column: Time_[s], Data Type: Int32
# Column: Cell_Type, Data Type: object
# Column: CAP, Data Type: float32
# Column: Cell_ID, Data Type: Int32
#    Row  Column  Plane  Timepoint  \
# 0    2       2      1          0
# 1    2       3      1          0
# 2    2       4      1          0
# 3    2       5      1          0
# 4    2       6      1          0
#
#    modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well  \
# 0                                                 9.9323
# 1                                                 8.1139
# 2                                                 8.0362
# 3                                                 8.0187
# 4                                                 6.9333
#
#    modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                         0.7347
# 1                                                         0.7045
# 2                                                         0.7020
# 3                                                         0.6904
# 4                                                         0.6732
#
#    modified_spots_chanel_3_Number_of_Spots_Mean_per_Well  \
# 0                                                 1.1754
# 1                                                 1.1104
# 2                                                 1.1116
# 3                                                 1.0961
# 4                                                 1.0572
#
#    modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well  \
# 0                                                                                     0.1521
# 1                                                                                     0.1679
# 2                                                                                     0.1698
# 3                                                                                     0.1673
# 4                                                                                     0.1785
#
#    spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                      0.8083
# 1                                                      0.7913
# 2                                                      0.7886
# 3                                                      0.7857
# 4                                                      0.7734
#
#    spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well  ...  \
# 0                                                      74.4842  ...
# 1                                                      60.3562  ...
# 2                                                      57.2979  ...
# 3                                                      57.0361  ...
# 4                                                      49.0347  ...
#
#    ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well  \
# 0                                                   55549.0352
# 1                                                   53193.0391
# 2                                                   52188.7891
# 3                                                   61699.5859
# 4                                                   62110.9531
#
#    ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well  \
# 0                                                  419614.0000
# 1                                                  478959.0625
# 2                                                  499264.0938
# 3                                                  467984.8125
# 4                                                  516490.2812
#
#    total_ir_chanel_4_normalized  total_ir_chanel_3_normalized  \
# 0                      148.5268                     1121.9625
# 1                      136.3924                     1228.1002
# 2                      140.2924                     1342.1078
# 3                      141.5128                     1073.3596
# 4                      148.5908                     1235.6227
#
#    Number_of_Analyzed_Fields  Height_[µm]  Time_[s]  Cell_Type       CAP  \
# 0                         25            0         0         HD   74.5763
# 1                         25            0         0         HC    0.0000
# 2                         25            0         0         HD   96.1479
# 3                         25            0         0         HC    0.0000
# 4                         25            0         0         HD  130.6626
#
#    Cell_ID
# 0     4717
# 1     1650
# 2     4819
# 3      848
# 4     4200
#
# [5 rows x 51 columns]
# 4717 ['HD']
# 1650 ['HC']
# 4819 ['HD']
# 848 ['HC']
# 4200 ['HD']
# 4719 ['HD']
# 1653 ['HC']
# 4721 ['HD']
# 4287 ['HD']
# Patients_Catalog: match 4287 --> GM04287
# Patients_Catalog: match 4721 --> GM04721
# Patients_Catalog: match 1650 --> GM01650
# Patients_Catalog: match 4200 --> GM04200
# Patients_Catalog: match 4717 --> GM04717
# Patients_Catalog: match 4719 --> GM04719
# Patients_Catalog: match 1653 --> GM01653
# Patients_Catalog: match 4819 --> GM04819
# Patients_Catalog: match 0848 --> NA0848
# Patient_ID
# NA0848     12
# GM04717     6
# GM01650     6
# GM04819     6
# GM04200     6
# GM04719     6
# GM01653     6
# GM04721     6
# GM04287     6
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp6  05.02.23__2023-02-19T12_14_21-Measurement 1.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp6  05.02.23__2023-02-19T12_14_21-Measurement 1.csv into 50 rows and 51 columns
# 11 Integers columns: ['Row', 'Column', 'Plane', 'Timepoint', 'all_cells_Number_of_Objects', 'all_cells_chanel_3_Intensity_Sum_Sum_per_Well', 'all_cells_chanel_4_Intensity_Sum_Sum_per_Well', 'Number_of_Analyzed_Fields', 'Height_[µm]', 'Time_[s]', 'Cell_ID']
# 39 Float columns: ['modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well', 'modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well', 'spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Contrast_Mean_per_Well', 'spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well', 'spots_chanel_3_final_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well', 'modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_3_Intensity_Mean_Mean_per_Well', 'all_cells_chanel_2_Area_[µm²]_Mean_per_Well', 'all_cells_Intensity_chanel_2_Mean_Mean_per_Well', 'all_cells_chanel_1_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well', 'all_cells_Intensity_chanel_1_Mean_Mean_per_Well', 'all_cells_chanel_4_Intensity_Mean_Mean_per_Well', 'all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well', 'ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well', 'ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well', 'ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well', 'total_ir_chanel_4_normalized', 'total_ir_chanel_3_normalized', 'CAP']
# 1 Strings columns: ['Cell_Type']
# Column: Row, Data Type: Int32
# Column: Column, Data Type: Int32
# Column: Plane, Data Type: Int32
# Column: Timepoint, Data Type: Int32
# Column: modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Contrast_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Number_of_Objects, Data Type: Int32
# Column: all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_chanel_2_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_2_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_1_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: total_ir_chanel_4_normalized, Data Type: float32
# Column: total_ir_chanel_3_normalized, Data Type: float32
# Column: Number_of_Analyzed_Fields, Data Type: Int32
# Column: Height_[µm], Data Type: Int32
# Column: Time_[s], Data Type: Int32
# Column: Cell_Type, Data Type: object
# Column: CAP, Data Type: float32
# Column: Cell_ID, Data Type: Int32
#    Row  Column  Plane  Timepoint  \
# 0    2       2      1          0
# 1    2       3      1          0
# 2    2       4      1          0
# 3    2       5      1          0
# 4    2       6      1          0
#
#    modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well  \
# 0                                                 7.3723
# 1                                                 7.1469
# 2                                                 6.5692
# 3                                                 6.9329
# 4                                                 6.9461
#
#    modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                         0.6580
# 1                                                         0.6723
# 2                                                         0.6546
# 3                                                         0.6724
# 4                                                         0.6649
#
#    modified_spots_chanel_3_Number_of_Spots_Mean_per_Well  \
# 0                                                 1.0525
# 1                                                 1.0530
# 2                                                 1.0289
# 3                                                 1.0598
# 4                                                 1.0463
#
#    modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well  \
# 0                                                                                     0.1729
# 1                                                                                     0.1778
# 2                                                                                     0.1824
# 3                                                                                     0.1798
# 4                                                                                     0.1791
#
#    spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                      0.7735
# 1                                                      0.7754
# 2                                                      0.7644
# 3                                                      0.7731
# 4                                                      0.7724
#
#    spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well  ...  \
# 0                                                      50.1743  ...
# 1                                                      49.8042  ...
# 2                                                      44.4432  ...
# 3                                                      47.7597  ...
# 4                                                      49.0617  ...
#
#    ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well  \
# 0                                                   63496.9805
# 1                                                   33438.4805
# 2                                                   54231.0781
# 3                                                   48627.2969
# 4                                                   51593.6836
#
#    ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well  \
# 0                                                  321200.2812
# 1                                                  217023.7031
# 2                                                  283957.1562
# 3                                                  407820.2188
# 4                                                  353413.7812
#
#    total_ir_chanel_4_normalized  total_ir_chanel_3_normalized  \
# 0                      136.5526                      690.7533
# 1                      124.7704                      809.7900
# 2                      128.5097                      672.8842
# 3                      121.5682                     1019.5505
# 4                      127.3918                      872.6266
#
#    Number_of_Analyzed_Fields  Height_[µm]  Time_[s]  Cell_Type       CAP  \
# 0                         25            0         0         HD   69.3374
# 1                         25            0         0         HC    0.0000
# 2                         25            0         0         HD  110.9399
# 3                         25            0         0         HC    0.0000
# 4                         25            0         0         HD  129.4299
#
#    Cell_ID
# 0     4689
# 1     1650
# 2     4715
# 3     1653
# 4      305
#
# [5 rows x 51 columns]
# 4689 ['HD']
# 1650 ['HC']
# 4715 ['HD']
# 1653 ['HC']
# 305 ['HD']
# 143 ['HC']
# 4717 ['HD']
# 495 ['HC']
# 4887 ['HD']
# 4687 ['HD']
# Patients_Catalog: match 0143 --> NA0143
# Patients_Catalog: match 0495 --> NA0495
# Patients_Catalog: match 4715 --> GM04715
# Patients_Catalog: match 0305 --> GM00305
# Patients_Catalog: match 1650 --> GM01650
# Patients_Catalog: match 4717 --> GM04717
# Patients_Catalog: match 4887 --> GM04887
# Patients_Catalog: match 4687 --> GM04687
# Patients_Catalog: match 1653 --> GM01653
# Patients_Catalog: match 4689 --> GM04689
# Patient_ID
# GM04689    5
# GM01650    5
# GM01653    5
# GM00305    5
# NA0143     5
# GM04717    5
# GM04887    5
# NA0495     5
# GM04687    5
# GM04715    4
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp7 06.02.23__2023-02-19T14_31_42-Measurement 1.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp7 06.02.23__2023-02-19T14_31_42-Measurement 1.csv into 60 rows and 51 columns
# 11 Integers columns: ['Row', 'Column', 'Plane', 'Timepoint', 'all_cells_Number_of_Objects', 'all_cells_chanel_3_Intensity_Sum_Sum_per_Well', 'all_cells_chanel_4_Intensity_Sum_Sum_per_Well', 'Number_of_Analyzed_Fields', 'Height_[µm]', 'Time_[s]', 'Cell_ID']
# 39 Float columns: ['modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well', 'modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well', 'spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Contrast_Mean_per_Well', 'spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well', 'spots_chanel_3_final_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well', 'modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_3_Intensity_Mean_Mean_per_Well', 'all_cells_chanel_2_Area_[µm²]_Mean_per_Well', 'all_cells_Intensity_chanel_2_Mean_Mean_per_Well', 'all_cells_chanel_1_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well', 'all_cells_Intensity_chanel_1_Mean_Mean_per_Well', 'all_cells_chanel_4_Intensity_Mean_Mean_per_Well', 'all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well', 'ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well', 'ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well', 'ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well', 'total_ir_chanel_4_normalized', 'total_ir_chanel_3_normalized', 'CAP']
# 1 Strings columns: ['Cell_Type']
# Column: Row, Data Type: Int32
# Column: Column, Data Type: Int32
# Column: Plane, Data Type: Int32
# Column: Timepoint, Data Type: Int32
# Column: modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Contrast_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Number_of_Objects, Data Type: Int32
# Column: all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_chanel_2_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_2_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_1_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: total_ir_chanel_4_normalized, Data Type: float32
# Column: total_ir_chanel_3_normalized, Data Type: float32
# Column: Number_of_Analyzed_Fields, Data Type: Int32
# Column: Height_[µm], Data Type: Int32
# Column: Time_[s], Data Type: Int32
# Column: Cell_Type, Data Type: object
# Column: CAP, Data Type: float32
# Column: Cell_ID, Data Type: Int32
#    Row  Column  Plane  Timepoint  \
# 0    2       2      1          0
# 1    2       3      1          0
# 2    2       4      1          0
# 3    2       5      1          0
# 4    2       6      1          0
#
#    modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well  \
# 0                                                 6.4762
# 1                                                 5.7046
# 2                                                 6.8974
# 3                                                 6.0908
# 4                                                 6.1899
#
#    modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                         0.6586
# 1                                                         0.6427
# 2                                                         0.6586
# 3                                                         0.6423
# 4                                                         0.6408
#
#    modified_spots_chanel_3_Number_of_Spots_Mean_per_Well  \
# 0                                                 1.0156
# 1                                                 0.9793
# 2                                                 1.0313
# 3                                                 0.9922
# 4                                                 0.9962
#
#    modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well  \
# 0                                                                                     0.1848
# 1                                                                                     0.1918
# 2                                                                                     0.1790
# 3                                                                                     0.1863
# 4                                                                                     0.1842
#
#    spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                      0.7642
# 1                                                      0.7582
# 2                                                      0.7686
# 3                                                      0.7598
# 4                                                      0.7620
#
#    spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well  ...  \
# 0                                                      45.5001  ...
# 1                                                      42.6182  ...
# 2                                                      48.2555  ...
# 3                                                      43.0279  ...
# 4                                                      44.4613  ...
#
#    ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well  \
# 0                                                   20449.5469
# 1                                                   44420.3867
# 2                                                   37746.0078
# 3                                                   24134.5996
# 4                                                   35261.5234
#
#    ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well  \
# 0                                                  197645.7344
# 1                                                  253895.9219
# 2                                                  251173.2031
# 3                                                  206643.8125
# 4                                                  249962.5312
#
#    total_ir_chanel_4_normalized  total_ir_chanel_3_normalized  \
# 0                      117.5261                     1135.8950
# 1                      101.8816                      582.3301
# 2                      117.2236                      780.0410
# 3                       88.7301                      759.7199
# 4                      133.0623                      943.2548
#
#    Number_of_Analyzed_Fields  Height_[µm]  Time_[s]  Cell_Type       CAP  \
# 0                         25            0         0         HD   76.2712
# 1                         25            0         0         HC    0.0000
# 2                         25            0         0         HD   94.1448
# 3                         25            0         0         HC    0.0000
# 4                         25            0         0         HD  126.3482
#
#    Cell_ID
# 0     4693
# 1     1650
# 2     4799
# 3     1653
# 4     4807
#
# [5 rows x 51 columns]
# 4693 ['HD']
# 1650 ['HC']
# 4799 ['HD']
# 1653 ['HC']
# 4807 ['HD']
# 730 ['HC']
# 4837 ['HD']
# 848 ['HC']
# 4212 ['HD']
# 4709 ['HD']
# Patients_Catalog: match 4837 --> GM04837
# Patients_Catalog: match 0730 --> NA0730
# Patients_Catalog: match 1650 --> GM01650
# Patients_Catalog: match 4709 --> GM04709
# Patients_Catalog: match 4212 --> GM04212
# Patients_Catalog: match 1653 --> GM01653
# Patients_Catalog: match 4799 --> GM04799
# Patients_Catalog: match 4693 --> GM04693
# Patients_Catalog: match 0848 --> NA0848
# Patients_Catalog: match 4807 --> GM04807
# Patient_ID
# GM04693    6
# GM01650    6
# GM04799    6
# GM01653    6
# GM04807    6
# NA0730     6
# NA0848     6
# GM04212    6
# GM04709    6
# GM04837    5
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp8 12.02.23__2023-02-20T14_52_23-Measurement 1.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- exp8 12.02.23__2023-02-20T14_52_23-Measurement 1.csv into 61 rows and 51 columns
# 11 Integers columns: ['Row', 'Column', 'Plane', 'Timepoint', 'all_cells_Number_of_Objects', 'all_cells_chanel_3_Intensity_Sum_Sum_per_Well', 'all_cells_chanel_4_Intensity_Sum_Sum_per_Well', 'Number_of_Analyzed_Fields', 'Height_[µm]', 'Time_[s]', 'Cell_ID']
# ...
# 3                                                 4.6022
# 4                                                 4.5101
#
#    modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                         0.5853
# 1                                                         0.5754
# 2                                                         0.5858
# 3                                                         0.5826
# 4                                                         0.5858
#
#    modified_spots_chanel_3_Number_of_Spots_Mean_per_Well  \
# 0                                                 0.9028
# 1                                                 0.8798
# 2                                                 0.8999
# 3                                                 0.8875
# 4                                                 0.8886
#
#    modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well  \
# 0                                                                                     0.1905
# 1                                                                                     0.2000
# 2                                                                                     0.1825
# 3                                                                                     0.1956
# 4                                                                                     0.1990
#
#    spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                      0.7281
# 1                                                      0.7199
# 2                                                      0.7321
# 3                                                      0.7230
# 4                                                      0.7216
#
#    spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well  ...  \
# 0                                                      30.7241  ...
# 1                                                      29.3998  ...
# 2                                                      32.7739  ...
# 3                                                      30.0027  ...
# 4                                                      30.1987  ...
#
#    ir_chanel_4_total_ir_chanel_4_total_Area_[ֲµmֲ²]_Sum_per_Well  \
# 0                                                      9380.5801
# 1                                                     20288.9941
# 2                                                      8590.6445
# 3                                                     17156.8730
# 4                                                     18146.5742
#
#    ir_chanel_3_total_ir_chanel_3_total_Area_[ֲµmֲ²]_Sum_per_Well  \
# 0                                                     20423.6504
# 1                                                     28122.0117
# 2                                                     22434.8672
# 3                                                     24980.2715
# 4                                                     27075.0938
#
#    total_ir_chanel_4_normalized  total_ir_chanel_3_normalized  \
# 0                       43.8345                       95.4376
# 1                       67.1821                       93.1192
# 2                       35.7944                       93.4786
# 3                       64.0182                       93.2100
# 4                       49.7166                       74.1783
#
#    Number_of_Analyzed_Fields  Height_[ֲµm]  Time_[s]  Cell_Type       CAP  \
# 0                         25             0         0         HD  106.0092
# 1                         25             0         0         HD  129.4299
# 2                         25             0         0         HD  106.0092
# 3                         25             0         0         HD  129.4299
# 4                         25             0         0         HD  129.4299
#
#    Cell_ID
# 0     4767
# 1     4285
# 2     4767
# 3     4285
# 4     4285
#
# [5 rows x 51 columns]
# 4767 ['HD']
# 4285 ['HD']
# Patients_Catalog: match 4767 --> GM04767
# Patients_Catalog: match 4285 --> GM04285
# Patient_ID
# GM04285    6
# GM04767    2
# Name: Num_Wells, dtype: int64
# Reading HGPS_Plate_Results: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- S exp4 05.07.22__2022-07-12T10_09_44-Measurement 1.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\LaminB\PlateResults - LaminB+a actinin- S exp4 05.07.22__2022-07-12T10_09_44-Measurement 1.csv into 47 rows and 51 columns
# 11 Integers columns: ['Row', 'Column', 'Plane', 'Timepoint', 'all_cells_Number_of_Objects', 'all_cells_chanel_3_Intensity_Sum_Sum_per_Well', 'all_cells_chanel_4_Intensity_Sum_Sum_per_Well', 'Number_of_Analyzed_Fields', 'Height_[µm]', 'Time_[s]', 'Cell_ID']
# 39 Float columns: ['modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well', 'modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_Mean_per_Well', 'modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well', 'spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well', 'spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Contrast_Mean_per_Well', 'spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well', 'spots_chanel_3_final_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well', 'spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well', 'modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well', 'modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well', 'all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well', 'all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well', 'all_cells_chanel_3_Intensity_Mean_Mean_per_Well', 'all_cells_chanel_2_Area_[µm²]_Mean_per_Well', 'all_cells_Intensity_chanel_2_Mean_Mean_per_Well', 'all_cells_chanel_1_Area_[µm²]_Mean_per_Well', 'all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well', 'all_cells_Intensity_chanel_1_Mean_Mean_per_Well', 'all_cells_chanel_4_Intensity_Mean_Mean_per_Well', 'all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well', 'ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well', 'ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well', 'ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well', 'total_ir_chanel_4_normalized', 'total_ir_chanel_3_normalized', 'CAP']
# 1 Strings columns: ['Cell_Type']
# Column: Row, Data Type: Int32
# Column: Column, Data Type: Int32
# Column: Plane, Data Type: Int32
# Column: Timepoint, Data Type: Int32
# Column: modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_Mean_per_Well, Data Type: float32
# Column: modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Uncorrected_Spot_Peak_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Contrast_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Background_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_Area_[px²]_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Spot_to_Region_Intensity_Mean_per_Well, Data Type: float32
# Column: spots_chanel_3_final_Intensity_Spot_chanel_3_Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_Intensity_modified_ir_chanel_3_at__Mean_Mean_per_Well, Data Type: float32
# Column: modified_ir_chanel_3_at_modified_ir_chanel_3_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Number_of_Objects, Data Type: Int32
# Column: all_cells_chanel_3_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Gabor_Max_2_px_w2_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Spot_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Hole_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Ridge_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_SER_Valley_1_px_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_3_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_chanel_2_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_2_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_1_Ratio_Width_to_Length_Mean_per_Well, Data Type: float32
# Column: all_cells_Intensity_chanel_1_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Mean_Mean_per_Well, Data Type: float32
# Column: all_cells_chanel_4_Intensity_Sum_Sum_per_Well, Data Type: Int32
# Column: all_cells_Intensity_ir_chanel_4_at_Mean_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_at_ir_chanel_4_at_Area_[µm²]_Mean_per_Well, Data Type: float32
# Column: ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well, Data Type: float32
# Column: total_ir_chanel_4_normalized, Data Type: float32
# Column: total_ir_chanel_3_normalized, Data Type: float32
# Column: Number_of_Analyzed_Fields, Data Type: Int32
# Column: Height_[µm], Data Type: Int32
# Column: Time_[s], Data Type: Int32
# Column: Cell_Type, Data Type: object
# Column: CAP, Data Type: float32
# Column: Cell_ID, Data Type: Int32
#    Row  Column  Plane  Timepoint  \
# 0    2       2      1          0
# 1    2       3      1          0
# 2    2       4      1          0
# 3    2       5      1          0
# 4    2       6      1          0
#
#    modified_spots_chanel_3_Total_Spot_Area_Mean_per_Well  \
# 0                                                 5.1408
# 1                                                 5.3672
# 2                                                 4.7087
# 3                                                 4.9358
# 4                                                 4.6788
#
#    modified_spots_chanel_3_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                         0.5937
# 1                                                         0.5891
# 2                                                         0.5857
# 3                                                         0.6024
# 4                                                         0.5811
#
#    modified_spots_chanel_3_Number_of_Spots_Mean_per_Well  \
# 0                                                 0.9073
# 1                                                 0.9083
# 2                                                 0.8977
# 3                                                 0.9115
# 4                                                 0.8984
#
#    modified_spots_chanel_3_Number_of_Spots_per_Area_of_modified_spots_chanel_3_Mean_per_Well  \
# 0                                                                                     0.1885
# 1                                                                                     0.1859
# 2                                                                                     0.1940
# 3                                                                                     0.1932
# 4                                                                                     0.1948
#
#    spots_chanel_3_final_Relative_Spot_Intensity_Mean_per_Well  \
# 0                                                      0.7343
# 1                                                      0.7327
# 2                                                      0.7271
# 3                                                      0.7338
# 4                                                      0.7240
#
#    spots_chanel_3_final_Corrected_Spot_Intensity_Mean_per_Well  ...  \
# 0                                                      33.1506  ...
# 1                                                      32.8458  ...
# 2                                                      30.1341  ...
# 3                                                      32.4477  ...
# 4                                                      29.7609  ...
#
#    ir_chanel_4_total_ir_chanel_4_total_Area_[µm²]_Sum_per_Well  \
# 0                                                   26697.5117
# 1                                                   28842.6465
# 2                                                   23824.5918
# 3                                                   10527.6270
# 4                                                   42150.4609
#
#    ir_chanel_3_total_ir_chanel_3_total_Area_[µm²]_Sum_per_Well  \
# 0                                                   73479.8125
# 1                                                   67655.3047
# 2                                                   69579.9531
# 3                                                   43909.6289
# 4                                                   77551.8203
#
#    total_ir_chanel_4_normalized  total_ir_chanel_3_normalized  \
# 0                       68.4552                      188.4098
# 1                       79.2380                      185.8662
# 2                       58.8262                      171.8024
# 3                       50.3714                      210.0939
# 4                       73.4329                      135.1077
#
#    Number_of_Analyzed_Fields  Height_[µm]  Time_[s]  Cell_Type       CAP  \
# 0                         25            0         0         HD  114.0216
# 1                         25            0         0         HC    0.0000
# 2                         25            0         0         HD  114.6379
# 3                         24            0         0         HC    0.0000
# 4                         25            0         0         HD  103.5439
#
#    Cell_ID
# 0     4687
# 1     1650
# 2     4691
# 3     1170
# 4     4849
#
# [5 rows x 51 columns]
# 4687 ['HD']
# 1650 ['HC']
# 4691 ['HD']
# 1170 ['HC']
# 4849 ['HD']
# 4807 ['HD']
# 848 ['HC']
# 4767 ['HD']
# 1653 ['HC']
# 143 ['HC']
# Patients_Catalog: match 1170 --> NA1170
# Patients_Catalog: match 4691 --> GM04691
# Patients_Catalog: match 0143 --> NA0143
# Patients_Catalog: match 1650 --> GM01650
# Patients_Catalog: match 4767 --> GM04767
# Patients_Catalog: match 4849 --> GM04849
# Patients_Catalog: match 4687 --> GM04687
# Patients_Catalog: match 1653 --> GM01653
# Patients_Catalog: match 0848 --> NA0848
# Patients_Catalog: match 4807 --> GM04807
# Patient_ID
# GM04687    6
# GM04691    6
# GM04849    6
# NA1170     6
# GM04807    6
# GM04767    4
# GM01650    3
# NA0848     3
# GM01653    3
# NA0143     3
# Name: Num_Wells, dtype: int64

# %%
DataFileLatB = Migration_Data(file_name_DataFileLatB, verbose=2)
# Out:
# Reading Migration_Data: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileLatB.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileLatB.csv into 4448 rows and 16 columns
# 1 Integers columns: ['CellID']
# 11 Float columns: ['Dnp', 'Dp', 'Dtot', 'MSD10', 'Pnp', 'Snp', 'Pp', 'Sp', 'SP10', 'Psi', 'CAP']
# 4 Strings columns: ['CellType', 'Patient', 'CAPPatient', 'CAPPatient2']
# Column: CellID, Data Type: Int32
# Column: Dnp, Data Type: float32
# Column: Dp, Data Type: float32
# Column: Dtot, Data Type: float32
# Column: MSD10, Data Type: float32
# Column: Pnp, Data Type: float32
# Column: Snp, Data Type: float32
# Column: Pp, Data Type: float32
# Column: Sp, Data Type: float32
# Column: SP10, Data Type: float32
# Column: Psi, Data Type: float32
# Column: CellType, Data Type: object
# Column: Patient, Data Type: object
# Column: CAP, Data Type: float32
# Column: CAPPatient, Data Type: object
# Column: CAPPatient2, Data Type: object
#    CellID     Dnp      Dp    Dtot       MSD10      Pnp     Snp        Pp  \
# 0       1  0.0543  0.3031  0.3574    769.1829   0.8113  0.5174    0.9321
# 1       2  0.6074  1.9282  2.5356   1337.5328   0.9522  1.5973    0.0193
# 2       3  0.0848  0.6129  0.6977    529.5131  48.0389  0.0840    0.9552
# 3       4  2.1528  6.8234  8.9763  14568.6602   2.4787  1.8639    0.9676
# 4       5  0.1206  2.9912  3.1119   1094.2180  53.0264  0.0954  999.9994
#
#         Sp     SP10      Psi CellType Patient  CAP      CAPPatient  \
# 0   1.1405   2.7734   5.5823     'HC'   0'HC'  0.0  0'HC - AG01512
# 1  19.9997   3.6572   3.1745     'HC'   0'HC'  0.0  0'HC - AG01512
# 2   1.6021   2.3011   7.2286     'HC'   0'HC'  0.0  0'HC - AG01512
# 3   5.3112  12.0701   3.1695     'HC'   0'HC'  0.0  0'HC - AG01512
# 4   0.1094   3.3079  24.7963     'HC'   0'HC'  0.0  0'HC - AG01512
#
#            CAPPatient2
# 0  0'HC - AG01512_B21'
# 1  0'HC - AG01512_B21'
# 2  0'HC - AG01512_B21'
# 3  0'HC - AG01512_B21'
# 4  0'HC - AG01512_B21'
# Reading cap_patient="0'HC - AG01512" --> raw_id='AG01512'
# Reading cap_patient="0'HC - NA07309" --> raw_id='NA07309'
# Reading cap_patient="0'HC - NA08788" --> raw_id='NA08788'
# Reading cap_patient="0'HCMedia - AG01512" --> raw_id='AG01512'
# Reading cap_patient="0'HCMedia - NA07309" --> raw_id='NA07309'
# Reading cap_patient="0'HCMedia - NA08788" --> raw_id='NA08788'
# Reading cap_patient="100'HD - GM0421211" --> raw_id='GM0421211'
# Reading cap_patient="96'HD - GM0481913" --> raw_id='GM0481913'
# Reading cap_patient="100'HDMedia - GM0421211" --> raw_id='GM0421211'
# Reading cap_patient="96'HDMedia - GM0481913" --> raw_id='GM0481913'
# Reading cap_patient="100'LatBHigh - GM0421211" --> raw_id='GM0421211'
# Reading cap_patient="96'LatBHigh - GM0481913" --> raw_id='GM0481913'
# Reading cap_patient="100'LatBLow - GM0421211" --> raw_id='GM0421211'
# Reading cap_patient="96'LatBLow - GM0481913" --> raw_id='GM0481913'
# CAPPatient
# 0'HC - AG01512               AG0015
# 0'HC - NA07309               NA0730
# 0'HC - NA08788               NA0878
# 0'HCMedia - AG01512          AG0015
# 0'HCMedia - NA07309          NA0730
# 0'HCMedia - NA08788          NA0878
# 100'HD - GM0421211          GM04212
# 96'HD - GM0481913           GM04819
# 100'HDMedia - GM0421211     GM04212
# 96'HDMedia - GM0481913      GM04819
# 100'LatBHigh - GM0421211    GM04212
# 96'LatBHigh - GM0481913     GM04819
# 100'LatBLow - GM0421211     GM04212
# 96'LatBLow - GM0481913      GM04819
# Name: Patient_ID, dtype: object
# Patient_ID
# AG0015     4
# NA0730     4
# NA0878     4
# GM04212    1
# GM04819    1
# Name: Num_Wells, dtype: int64

# %%
DataFileMitoQ = Migration_Data(file_name_DataFileMitoQ, verbose=2)
# Out:
# Reading Migration_Data: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileMitoQ.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileMitoQ.csv into 20050 rows and 16 columns
# 1 Integers columns: ['CellID']
# 11 Float columns: ['Dnp', 'Dp', 'Dtot', 'MSD10', 'Pnp', 'Snp', 'Pp', 'Sp', 'SP10', 'Psi', 'CAP']
# 4 Strings columns: ['CellType', 'Patient', 'CAPPatient', 'CAPPatient2']
# Column: CellID, Data Type: Int32
# Column: Dnp, Data Type: float32
# Column: Dp, Data Type: float32
# Column: Dtot, Data Type: float32
# Column: MSD10, Data Type: float32
# Column: Pnp, Data Type: float32
# Column: Snp, Data Type: float32
# Column: Pp, Data Type: float32
# Column: Sp, Data Type: float32
# Column: SP10, Data Type: float32
# Column: Psi, Data Type: float32
# Column: CellType, Data Type: object
# Column: Patient, Data Type: object
# Column: CAP, Data Type: float32
# Column: CAPPatient, Data Type: object
# Column: CAPPatient2, Data Type: object
#    CellID     Dnp      Dp    Dtot      MSD10      Pnp     Snp       Pp  \
# 0       1  0.1732  1.8692  2.0424  6782.1699  18.1948  0.1952  37.9020
# 1       2  0.2344  3.2182  3.4527  6696.9766  15.7286  0.2442  84.2215
# 2       3  1.0935  2.4281  3.5216  8291.3057  62.9828  0.2635  75.4571
# 3       4  0.0154  1.6518  1.6673  1211.2532   0.8196  0.2744   0.9081
# 4       5  0.0857  0.0867  0.1725   157.8486   0.8835  0.6231   0.9147
#
#        Sp    SP10       Psi CellType Patient  CAP      CAPPatient  \
# 0  0.4441  8.2354   10.7895     'HC'   0'HC'  0.0  0'HC - NA01438
# 1  0.3910  8.1835   13.7277     'HC'   0'HC'  0.0  0'HC - NA01438
# 2  0.3588  9.1057    2.2205     'HC'   0'HC'  0.0  0'HC - NA01438
# 3  2.6975  3.4803  107.0947     'HC'   0'HC'  0.0  0'HC - NA01438
# 4  0.6159  1.2564    1.0117     'HC'   0'HC'  0.0  0'HC - NA01438
#
#           CAPPatient2
# 0  0'HC - NA01438_C4'
# 1  0'HC - NA01438_C4'
# 2  0'HC - NA01438_C4'
# 3  0'HC - NA01438_C4'
# 4  0'HC - NA01438_C4'
# Reading cap_patient="0'HC - NA01438" --> raw_id='NA01438'
# Reading cap_patient="0'HC - NA07309" --> raw_id='NA07309'
# Reading cap_patient="0'HCMedia - NA01438" --> raw_id='NA01438'
# Reading cap_patient="0'HCMedia - NA07309" --> raw_id='NA07309'
# Reading cap_patient="110'HD - GM041968" --> raw_id='GM041968'
# Reading cap_patient="100'HD - GM0421211" --> raw_id='GM0421211'
# Reading cap_patient="111'HD - GM0471511" --> raw_id='GM0471511'
# Reading cap_patient="110'HDMedia - GM041968" --> raw_id='GM041968'
# Reading cap_patient="100'HDMedia - GM0421211" --> raw_id='GM0421211'
# Reading cap_patient="111'HDMedia - GM0471511" --> raw_id='GM0471511'
# Reading cap_patient="110'MitoQ - GM041968" --> raw_id='GM041968'
# Reading cap_patient="100'MitoQ - GM0421211" --> raw_id='GM0421211'
# Reading cap_patient="111'MitoQ - GM0471511" --> raw_id='GM0471511'
# Reading cap_patient="0'HC - GM01653" --> raw_id='GM01653'
# Reading cap_patient="0'HC - NA0971" --> raw_id='NA0971'
# Reading cap_patient="0'HC - NA1170" --> raw_id='NA1170'
# Reading cap_patient="129'HD - GM00305" --> raw_id='GM00305'
# Reading cap_patient="141'HD - GM02165" --> raw_id='GM02165'
# Reading cap_patient="76'MitoQ - GM04847" --> raw_id='GM04847'
# Reading cap_patient="69'HD - GM04689" --> raw_id='GM04689'
# Reading cap_patient="76'HD - GM04693" --> raw_id='GM04693'
# Reading cap_patient="60'HD - GM04837" --> raw_id='GM04837'
# Reading cap_patient="76'HD - GM04847" --> raw_id='GM04847'
# Reading cap_patient="129'MitoQ - GM00305" --> raw_id='GM00305'
# Reading cap_patient="141'MitoQ - GM02165" --> raw_id='GM02165'
# Reading cap_patient="69'MitoQ - GM04689" --> raw_id='GM04689'
# Reading cap_patient="76'MitoQ - GM04693" --> raw_id='GM04693'
# Reading cap_patient="60'MitoQ - GM04837" --> raw_id='GM04837'
# Reading cap_patient="0'HC - NA0143" --> raw_id='NA0143'
# Reading cap_patient="129'HD - GM04285" --> raw_id='GM04285'
# Reading cap_patient="114'HD - GM04687" --> raw_id='GM04687'
# Reading cap_patient="115'HD - GM04691" --> raw_id='GM04691'
# Reading cap_patient="106'HD - GM04767" --> raw_id='GM04767'
# Reading cap_patient="126'HD - GM04807" --> raw_id='GM04807'
# Reading cap_patient="104'HD - GM04849" --> raw_id='GM04849'
# Reading cap_patient="129'MitoQ - GM04285" --> raw_id='GM04285'
# Reading cap_patient="114'MitoQ - GM04687" --> raw_id='GM04687'
# Reading cap_patient="115'MitoQ - GM04691" --> raw_id='GM04691'
# Reading cap_patient="106'MitoQ - GM04767" --> raw_id='GM04767'
# Reading cap_patient="126'MitoQ - GM04807" --> raw_id='GM04807'
# Reading cap_patient="104'MitoQ - GM04849" --> raw_id='GM04849'
# CAPPatient
# 0'HC - NA01438              NA0143
# 0'HC - NA07309              NA0730
# 0'HCMedia - NA01438         NA0143
# 0'HCMedia - NA07309         NA0730
# 110'HD - GM041968          GM04196
# 100'HD - GM0421211         GM04212
# 111'HD - GM0471511         GM04715
# 110'HDMedia - GM041968     GM04196
# 100'HDMedia - GM0421211    GM04212
# 111'HDMedia - GM0471511    GM04715
# 110'MitoQ - GM041968       GM04196
# 100'MitoQ - GM0421211      GM04212
# 111'MitoQ - GM0471511      GM04715
# 0'HC - GM01653             GM01653
# 0'HC - NA0971               NA0971
# 0'HC - NA1170               NA1170
# 129'HD - GM00305           GM00305
# 141'HD - GM02165           GM02165
# 76'MitoQ - GM04847         GM04847
# 69'HD - GM04689            GM04689
# 76'HD - GM04693            GM04693
# 60'HD - GM04837            GM04837
# 76'HD - GM04847            GM04847
# 129'MitoQ - GM00305        GM00305
# 141'MitoQ - GM02165        GM02165
# 69'MitoQ - GM04689         GM04689
# 76'MitoQ - GM04693         GM04693
# 60'MitoQ - GM04837         GM04837
# 0'HC - NA0143               NA0143
# 129'HD - GM04285           GM04285
# 114'HD - GM04687           GM04687
# 115'HD - GM04691           GM04691
# 106'HD - GM04767           GM04767
# 126'HD - GM04807           GM04807
# 104'HD - GM04849           GM04849
# 129'MitoQ - GM04285        GM04285
# 114'MitoQ - GM04687        GM04687
# 115'MitoQ - GM04691        GM04691
# 106'MitoQ - GM04767        GM04767
# 126'MitoQ - GM04807        GM04807
# 104'MitoQ - GM04849        GM04849
# Name: Patient_ID, dtype: object
# Patient_ID
# NA0143      5
# NA0730      2
# GM04196     2
# GM04212     3
# GM04715     2
# GM01653     8
# NA0971      6
# NA1170     11
# GM00305     2
# GM02165     2
# GM04847     2
# GM04689     2
# GM04693     2
# GM04837     3
# GM04285     1
# GM04687     1
# GM04691     3
# GM04767     3
# GM04807     2
# GM04849     2
# Name: Num_Wells, dtype: int64

# %%
DataFileWithHGPS = Migration_Data(file_name_DataFileWithHGPS, verbose=2)
# Out:
# Reading Migration_Data: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileWithHGPS.csv
# Done reading raw csv file: d:\projects\BioTAU\Huntington\datasets\Cell_Migration\Migration_Data_Excels\Migration\DataFileWithHGPS.csv into 26295 rows and 16 columns
# 1 Integers columns: ['CellID']
# 11 Float columns: ['Dnp', 'Dp', 'Dtot', 'MSD10', 'Pnp', 'Snp', 'Pp', 'Sp', 'SP10', 'Psi', 'CAP']
# 4 Strings columns: ['CellType', 'Patient', 'CAPPatient', 'CAPPatient2']
# Column: CellID, Data Type: Int32
# Column: Dnp, Data Type: float32
# Column: Dp, Data Type: float32
# Column: Dtot, Data Type: float32
# Column: MSD10, Data Type: float32
# Column: Pnp, Data Type: float32
# Column: Snp, Data Type: float32
# Column: Pp, Data Type: float32
# Column: Sp, Data Type: float32
# Column: SP10, Data Type: float32
# Column: Psi, Data Type: float32
# Column: CellType, Data Type: object
# Column: Patient, Data Type: object
# Column: CAP, Data Type: float32
# Column: CAPPatient, Data Type: object
# Column: CAPPatient2, Data Type: object
#    CellID     Dnp      Dp    Dtot      MSD10       Pnp     Snp        Pp  \
# 0       1  1.5061  0.9997  2.5058  2010.3746  189.5269  0.1783  999.9995
# 1       2  0.1309  2.3541  2.4850  2591.4485   14.9104  0.1874   28.8396
# 2       3  2.1138  2.6028  4.7166  4480.9277   23.8174  0.5958    1.4523
# 3       4  3.2336  1.2855  4.5191  6158.8022   40.9048  0.5623   17.1630
# 4       5  0.1535  0.7433  0.8969  1481.3047   45.4407  0.1163    0.9638
#
#        Sp    SP10      Psi CellType Patient  CAP  CAPPatient       CAPPatient2
# 0  0.0632  4.4837   0.6638     'HC'   0'HC'  0.0  0'NA014310  0'NA014310_E8_1'
# 1  0.5714  5.0906  17.9862     'HC'   0'HC'  0.0  0'NA014310  0'NA014310_E8_1'
# 2  2.6775  6.6940   1.2313     'HC'   0'HC'  0.0  0'NA014310  0'NA014310_E8_1'
# 3  0.5474  7.8478   0.3976     'HC'   0'HC'  0.0  0'NA014310  0'NA014310_E8_1'
# 4  1.7564  3.8488   4.8411     'HC'   0'HC'  0.0  0'NA014310  0'NA014310_E8_1'
# Reading cap_patient="0'NA014310" --> raw_id='NA014310'
# Reading cap_patient="0'NA049513" --> raw_id='NA049513'
# Reading cap_patient="0'NA084813" --> raw_id='NA084813'
# Reading cap_patient="0'NA097110" --> raw_id='NA097110'
# Reading cap_patient="0'NA117014" --> raw_id='NA117014'
# Reading cap_patient="0'NA0165017" --> raw_id='NA0165017'
# Reading cap_patient="0'NA0165320" --> raw_id='NA0165320'
# Reading cap_patient="0'NA4614610" --> raw_id='NA4614610'
# Reading cap_patient="0'NAIC016" --> raw_id='NA0016'
# Reading cap_patient="0'NAIC025" --> raw_id='NA0025'
# Reading cap_patient="0'NAIC143" --> raw_id='NA0143'
# Reading cap_patient="0'NAIC157" --> raw_id='NA0157'
# Reading cap_patient="0'NAIC170" --> raw_id='NA0170'
# Reading cap_patient="0'NAIC233" --> raw_id='NA0233'
# Reading cap_patient="0'NAIC234" --> raw_id='NA0234'
# Reading cap_patient="0'NAIC477" --> raw_id='NA0477'
# Reading cap_patient="0'NAIC561" --> raw_id='NA0561'
# Reading cap_patient="0'NAIC579" --> raw_id='NA0579'
# Reading cap_patient="0'NAIC633" --> raw_id='NA0633'
# Reading cap_patient="0'NAIC769" --> raw_id='NA0769'
# Reading cap_patient="0'NAIC878" --> raw_id='NA0878'
# Reading cap_patient="69'GM0468911" --> raw_id='GM0468911'
# Reading cap_patient="76'GM0469309" --> raw_id='GM0469309'
# Reading cap_patient="60'GM0483713" --> raw_id='GM0483713'
# Reading cap_patient="76'GM0484714" --> raw_id='GM0484714'
# Reading cap_patient="75'GMIC4717" --> raw_id='GM04717'
# Reading cap_patient="84'GMIC4719" --> raw_id='GM04719'
# Reading cap_patient="104'GM04484909" --> raw_id='GM04484909'
# Reading cap_patient="115'GM0469109" --> raw_id='GM0469109'
# Reading cap_patient="106'GM0476713" --> raw_id='GM0476713'
# Reading cap_patient="114'GM0568716" --> raw_id='GM0568716'
# Reading cap_patient="119'GMIC214712" --> raw_id='GM0214712'
# Reading cap_patient="110'GMIC41968" --> raw_id='GM041968'
# Reading cap_patient="100'GMIC42128" --> raw_id='GM042128'
# Reading cap_patient="111'GMIC4709" --> raw_id='GM04709'
# Reading cap_patient="111'GMIC4715" --> raw_id='GM04715'
# Reading cap_patient="91'GMIC4721" --> raw_id='GM04721'
# Reading cap_patient="94'GMIC47997" --> raw_id='GM047997'
# Reading cap_patient="96'GMIC48198" --> raw_id='GM048198'
# Reading cap_patient="111'GMIC48878" --> raw_id='GM048878'
# Reading cap_patient="129'GM0030518" --> raw_id='GM0030518'
# Reading cap_patient="141'GM0216516" --> raw_id='GM0216516'
# Reading cap_patient="129'GM0428510" --> raw_id='GM0428510'
# Reading cap_patient="126'GM04484715" --> raw_id='GM04484715'
# Reading cap_patient="131'GMIC4200" --> raw_id='GM04200'
# Reading cap_patient="126'GMIC4287" --> raw_id='GM04287'
# Reading cap_patient="132'GMIC447610" --> raw_id='GM0447610'
# Reading cap_patient="139'GMIC5031" --> raw_id='GM05031'
# Reading cap_patient="129'GMIC62748" --> raw_id='GM062748'
# Reading cap_patient="999'pro18816" --> raw_id='HGADFN18816'
# Reading cap_patient="999'pro27113" --> raw_id='HGADFN27113'
# Reading cap_patient="999'pro36713" --> raw_id='HGADFN36713'
# Reading cap_patient="999'pro12218" --> raw_id='HGADFN12218'
# Reading cap_patient="999'pro12716" --> raw_id='HGADFN12716'
# Reading cap_patient="999'pro16915" --> raw_id='HGADFN16915'
# CAPPatient
# 0'NA014310            NA0143
# 0'NA049513            NA0495
# 0'NA084813            NA0848
# 0'NA097110            NA0971
# 0'NA117014            NA1170
# 0'NA0165017          GM01650
# 0'NA0165320          GM01653
# 0'NA4614610          AG16146
# 0'NAIC016             NA0016
# 0'NAIC025             NA0025
# 0'NAIC143             NA0143
# 0'NAIC157             NA0157
# 0'NAIC170             NA0170
# 0'NAIC233             NA0233
# 0'NAIC234             NA0234
# 0'NAIC477             NA0477
# 0'NAIC561             NA0561
# 0'NAIC579             NA0579
# 0'NAIC633             NA0633
# 0'NAIC769             NA0769
# 0'NAIC878             NA0878
# 69'GM0468911         GM04689
# 76'GM0469309         GM04693
# 60'GM0483713         GM04837
# 76'GM0484714         GM04847
# 75'GMIC4717          GM04717
# 84'GMIC4719          GM04719
# 104'GM04484909       GM04849
# 115'GM0469109        GM04691
# 106'GM0476713        GM04767
# 114'GM0568716        GM04687
# 119'GMIC214712       GM02147
# 110'GMIC41968        GM04196
# 100'GMIC42128        GM04212
# 111'GMIC4709         GM04709
# 111'GMIC4715         GM04715
# 91'GMIC4721          GM04721
# 94'GMIC47997         GM04799
# 96'GMIC48198         GM04819
# 111'GMIC48878        GM04887
# 129'GM0030518        GM00305
# 141'GM0216516        GM02165
# 129'GM0428510        GM04285
# 126'GM04484715       GM04847
# 131'GMIC4200         GM04200
# 126'GMIC4287         GM04287
# 132'GMIC447610       GM04476
# 139'GMIC5031         GM05031
# 129'GMIC62748        GM06274
# 999'pro18816      HGADFN0188
# 999'pro27113      HGADFN0271
# 999'pro36713      HGADFN0367
# 999'pro12218      HGADFN0122
# 999'pro12716      HGADFN0127
# 999'pro16915      HGADFN0169
# Name: Patient_ID, dtype: object
# Patient_ID
# NA0143         1
# NA0495         6
# NA0848         3
# NA0971         6
# NA1170        18
# GM01650        3
# GM01653        9
# AG16146        6
# NA0016         1
# NA0025         1
# NA0157         1
# NA0170         1
# NA0233         1
# NA0234         1
# NA0477         1
# NA0561         1
# NA0579         1
# NA0633         1
# NA0769         1
# NA0878         1
# GM04689       12
# GM04693       12
# GM04837       12
# GM04847        6
# GM04717        1
# GM04719        1
# GM04849        6
# GM04691        6
# GM04767        6
# GM04687        6
# GM02147        1
# GM04196        1
# GM04212        1
# GM04709        1
# GM04715        1
# GM04721        1
# GM04799        1
# GM04819        1
# GM04887        1
# GM00305       12
# GM02165       11
# GM04285        6
# GM04200        1
# GM04287        1
# GM04476        1
# GM05031        1
# GM06274        1
# HGADFN0188     6
# HGADFN0271     6
# HGADFN0367     6
# HGADFN0122     6
# HGADFN0127     6
# HGADFN0169     6
# Name: Num_Wells, dtype: int64
